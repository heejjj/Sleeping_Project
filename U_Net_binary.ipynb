# %% [markdown]
# <a href="https://colab.research.google.com/github/heejjj/Sleeping_Project/blob/main/U_Net_binary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # weekday binary

# %%
weekday = pd.read_csv('/content/drive/MyDrive/KDT_project/Hackathon/CNNsegmentation/data/weekday.csv')
weekday = weekday.drop('Unnamed: 0', axis=1)
print(weekday.shape)
# Out:
# (1434, 7)

# %%
weekday["Duration (hr)"] = weekday["Duration (hr)"].astype('float') * 1000
weekday['Value']= weekday['Value'].replace('Core',1)
weekday['Value']= weekday['Value'].replace('REM',0)
weekday['Value']= weekday['Value'].replace('Deep',0)
weekday['Value']= weekday['Value'].replace('Awake',0)
tmp = weekday[["Duration (hr)", "Value"]]
tmp = np.array(tmp)

x_list = []
for x in tmp:
  if x[1] != 0:
    timeseries = np.ones([int(x[0])]) * x[1]
    x_list.append(timeseries)
  else:
    timeseries = np.zeros([int(x[0])])
    x_list.append(timeseries)

ts = np.concatenate(x_list)
print(ts.shape)
# Out:
# (378383,)

# %%
y = ts
x = np.arange(len(y))

plt.plot(x, y, color='black',linewidth=2)

# %%
## 해당 경로에 있는 .csv 파일명 리스트 가져오기

import os

path = '/content/drive/MyDrive/KDT_project/HACKATHON/data/day_split_weekday'
file_list = os.listdir(path)
file_name = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
cd /content/drive/MyDrive/KDT_project/HACKATHON/data/day_split_weekday
# Out:
# /content/drive/MyDrive/KDT_project/HACKATHON/data/day_split_weekday

# %%
len_list = []
for file in file_name:
  df = pd.read_csv(file)
  df = df.drop('Unnamed: 0', axis=1)

  tmp = df
  tmp["Duration (hr)"] = tmp["Duration (hr)"].astype('float') * 1000
  tmp['Value']= tmp['Value'].replace('Core',2)
  tmp['Value']= tmp['Value'].replace('REM',3)
  tmp['Value']= tmp['Value'].replace('Deep',1)
  tmp['Value']= tmp['Value'].replace('Awake',4)
  tmp = tmp[["Duration (hr)", "Value"]]
  tmp = np.array(tmp)

  x_list = []
  for x in tmp:
    if x[1] != 0:
      timeseries = np.ones([int(x[0])]) * x[1]
      x_list.append(timeseries)

  ts = np.concatenate(x_list)

  
  len_list.append(len(ts))

# %%
sum(len_list) / len(len_list)
# Out:
# 7567.66

# %%
import numpy as np
import tensorflow as tf

# 데이터 전처리를 위한 라이브러리
import json
from scipy.signal import butter, lfilter, medfilt

# 모델 학습을 위한 라이브러리
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, MaxPooling1D
from tensorflow.keras.layers import Conv1DTranspose, concatenate, Activation, SpatialDropout1D

# 성능평가 함수를 위한 라이브러리
from tensorflow.keras import backend as K

# 시각화를 위한 라이브러리
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd

weekday = pd.read_csv('/content/drive/MyDrive/KDT_project/Hackathon/CNNsegmentation/data/weekday.csv')
weekend = pd.read_csv('/content/drive/MyDrive/KDT_project/Hackathon/CNNsegmentation/data/weekend.csv')
weekday = weekday.drop('Unnamed: 0', axis=1)
weekend = weekend.drop('Unnamed: 0', axis=1)
print(weekday.shape, weekend.shape)
# Out:
# (1434, 7) (575, 7)

# %%
img_weekday = weekday.iloc[:,[2,3]]
img_weekday["Duration (hr)"] = img_weekday["Duration (hr)"].astype('float') * 1000
img_weekday['Value']= img_weekday['Value'].replace('Core',1)
img_weekday['Value']= img_weekday['Value'].replace('REM',0)
img_weekday['Value']= img_weekday['Value'].replace('Deep',0)
img_weekday['Value']= img_weekday['Value'].replace('Awake',0)
img_weekday = img_weekday[["Duration (hr)", "Value"]]
img_weekday = np.array(img_weekday)

x_list = []   # 라벨을 duration 만큼 반복한 array를 list에 append
for x in img_weekday:
  if x[1] != 0:
    timeseries = np.ones([int(x[0])]) * x[1]
    x_list.append(timeseries)
  else:
    timeseries = np.zeros([int(x[0])]) * x[1]
    x_list.append(timeseries)

ts = np.concatenate(x_list)[:-3383]   # 7567로 나누어떨어지기 위해 데이터 버림.
print(ts.shape)
ts
tmp = ts.reshape(50, 7500, -1)
print(tmp.shape)
# Out:
# (375000,)
# (50, 7500, 1)

# %%
# 변수 정의하기
# variables
FREQUENCY_OF_DATASET = 500   # 심박수 한 사이클. 1/Hz = 주기. 일단 해보고 바꾼다면 2000

num_classes = 2 # Core, Not-Core

# %% [markdown]
# # 데이터 증강

# %%
def augmentation(dataset, ratio = 0.8):
  train_idx = int(50 * ratio)  # 80%를 트레인세트로 분류
  idx = np.arange(50)        # 0 ~ 49
  np.random.shuffle(idx)

  x = dataset[:][idx]
  y = dataset[:][idx]

  # 2. Split into 8:2
  tmp_train_x = x[:train_idx]
  tmp_valid_x = x[train_idx:]
  tmp_train_y = y[:train_idx]
  tmp_valid_y = y[train_idx:]

  # 3. Augmentation on Train and Valid dataset
  # step 설명 : 250 (0.5초) 이동하며 4초 신호를 augmentation한다.
  step = 250

  N_train = 1500  # 여유있게 범위를 줌
  N_valid = 400

  train_x, train_y = np.zeros((N_train, 2000, 1), dtype=np.float32), np.zeros((N_train, 2000, 2), dtype=np.float32) 
  valid_x, valid_y = np.zeros((N_valid, 2000, 1), dtype=np.float32), np.zeros((N_valid, 2000, 2), dtype=np.float32) 
  # print(N_train, N_valid)
  print("Start Augmentation")

  # 4.1. Train
  t_cnt, v_cnt = 0, 0
  for patient in range(train_idx):
    tmp = tmp_train_y[patient]

    # tmp = np.argmax(tmp[:, 1:], axis=-1) 
    tmp = np.nonzero(tmp)[0]            # 0이 아닌 값들의 index 들을 반환해 주는 함수
    start_idx, end_idx = tmp[0], tmp[-1]
    length = end_idx - start_idx + 1

    tmp_x = tmp_train_x[patient, start_idx:end_idx + 1]
    tmp_y = tmp_train_y[patient, start_idx:end_idx + 1]
    for idx in range(0, length-2000, step):        # 원본 15초에서 6초만큼씩 잘라, step 만큼 이동하여 데이터 증강
      train_x[t_cnt] = tmp_x[idx:idx + 2000, :]
      train_y[t_cnt] = tmp_y[idx:idx + 2000, :]
      t_cnt += 1
  print(f"Number of Train set : {t_cnt}")

  # # 4.2. Valid
  for patient in range(50-train_idx):
    tmp = tmp_valid_y[patient]
    
    tmp = np.nonzero(tmp)[0]  
    start_idx, end_idx = tmp[0], tmp[-1]
    length = end_idx - start_idx + 1

    tmp_x = tmp_valid_x[patient, start_idx:end_idx + 1]
    tmp_y = tmp_valid_y[patient, start_idx:end_idx + 1]
    for idx in range(0, length-2000, step):
      valid_x[v_cnt] = tmp_x[idx:idx + 2000, :]
      valid_y[v_cnt] = tmp_y[idx:idx + 2000, :]
      v_cnt += 1
  print(f"Number of Valid set : {v_cnt}")

  train_x, train_y = train_x[:t_cnt], train_y[:t_cnt]
  valid_x, valid_y = valid_x[:v_cnt], valid_y[:v_cnt]

  # 5. Shuffle and Save
  print("\nStart saving the dataset...")
  idx = np.arange(t_cnt)
  np.random.shuffle(idx)
  train_x = train_x[idx]
  train_y = train_y[idx]

  np.save(f"train_x", train_x)
  np.save(f"train_y", train_y)

  np.save(f"valid_x", valid_x)
  np.save(f"valid_y", valid_y)
  print("Complete saving\n")

# %% [markdown]
# # 모델 설계

# %%
def UNet1D():
    num_filter = 16

    inputs = Input((2000, 1))  # length of 4 sec signal is 2,000

    # Encoder
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(inputs)
    # kernel_initializer : kernel가중치 행렬의 초기화 프로그램입니다( 참조 keras.initializers). 기본값은 'glorot_uniform'입니다.
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o1 = Activation('relu')(x)
    x = MaxPooling1D(2)(o1)

    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o2 = Activation('relu')(x)
    x = MaxPooling1D(2)(o2)

    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o3 = Activation('relu')(x)
    x = MaxPooling1D(2)(o3)

    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o4 = Activation('relu')(x)
    x = MaxPooling1D(2)(o4)

    x = Conv1D(num_filter*16, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*16, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)  

    # Decoder
    x = Conv1DTranspose(num_filter*8, 8, strides=2, padding='same')(x)
    print(x.shape, o4.shape)
    x = concatenate([x, o4])
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter*4, 8, strides=2, padding='same')(x)
    print(x.shape, o3.shape)
    x = concatenate([x, o3])
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter*2, 8, strides=2, padding='same')(x)
    print(x.shape, o2.shape)
    x = concatenate([x, o2])
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter, 8, strides=2, padding='same')(x)
    print(x.shape, o1.shape)
    x = concatenate([x, o1])
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    outputs = Conv1D(num_classes, 1, activation='softmax', kernel_initializer='he_normal')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # 성능평가 함수 정의

# %%
# 1. F1-Score = Dice score
def f1_score(y_true, y_pred):
    smooth = 0.0001
    intersection = K.sum(y_true * y_pred, axis=[1, 2])
    union = K.sum(y_true, axis=[1, 2]) + K.sum(y_pred, axis=[1, 2])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

class f1_loss(tf.losses.Loss):
    def __init__(self):
        super(f1_loss, self).__init__(reduction='auto', name="f1_loss")

    def call(self, y_true, y_pred):
        return 1 - f1_score(y_true, y_pred)


# 2. Jaccard = IoU
def Jaccard(y_true, y_pred):
    smooth = 0.0001
    intersection = K.sum(y_true * y_pred, axis=[1, 2])
    union = K.sum(y_true, axis=[1, 2]) + K.sum(y_pred, axis=[1, 2])
    return K.mean((intersection + smooth) / (union - intersection + smooth), axis=0)

class JaccardLoss(tf.losses.Loss):
    def __init__(self):
        super(JaccardLoss, self).__init__(reduction='auto', name="JaccardLoss")

    def call(self, y_true, y_pred):
        return 1 - Jaccard(y_true, y_pred)

# %% [markdown]
# # 예측함수 정의

# %%
def Predict(test, n_sample=5):
    '''
    Input
        - test: [valid_x, valid_y]
        - n_sample: 보여줄 샘플 갯수
    테스트셋에 대해서 예측한 결과와 실제 labeling 데이터를 시각화한다.    
    '''
    model = UNet1D()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
                  loss='binary_crossentropy',
                  metrics=[Jaccard, f1_score])
    model.load_weights("weights.h5")

    for i, test_ecg in enumerate(test[0]): # valid_x
        pred = model.predict(np.reshape(test_ecg, (1, 2000, 1)))
        true = np.argmax(test[1][i], axis=-1)
        pred = np.argmax(pred[0], axis=-1)

        fig, ax = plt.subplots(3, 1, figsize=(20, 12))

        ax[0].plot(test_ecg[:, 1])
        ax[0].set_title(f"ECG_{i}'s lead II", fontsize=10)

        ax[1].plot(true)
        ax[1].set_title(f"ECG_{i}'s Groud Truth", fontsize=10)

        ax[2].plot(pred)
        ax[2].set_title(f"ECG_{i}'s Prediction", fontsize=10)

        plt.show()
        
        # 20개의 샘플만 보여준 후 멈춤
        if i == n_sample - 1:
            break

# %% [markdown]
# # 데이터 증강

# %%
# Augmentation
augmentation(tmp)
del tmp
# Out:
# Start Augmentation
# Number of Train set : 867
# Number of Valid set : 220
#
# Start saving the dataset...
# Complete saving

# %%
# 데이터 로드
train = [np.load("train_x.npy"), np.load("train_y.npy")]
valid = [np.load("valid_x.npy"), np.load("valid_y.npy")]

# %% [markdown]
# # 모델 학습

# %%
# 4. Model
print("Start Training")
batch_size = 256
lr = 0.005
epochs = 200

model = UNet1D()
model.summary()
# Out:
# Start Training
# (None, 250, 128) (None, 250, 128)
# (None, 500, 64) (None, 500, 64)
# (None, 1000, 32) (None, 1000, 32)
# (None, 2000, 16) (None, 2000, 16)
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 2000, 1)]    0           []
#
#  conv1d_57 (Conv1D)             (None, 2000, 16)     160         ['input_4[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 2000, 16)    64          ['conv1d_57[0][0]']
#  ormalization)
#
#  spatial_dropout1d_54 (SpatialD  (None, 2000, 16)    0           ['batch_normalization_54[0][0]']
#  ropout1D)
#
#  activation_54 (Activation)     (None, 2000, 16)     0           ['spatial_dropout1d_54[0][0]']
#
#  conv1d_58 (Conv1D)             (None, 2000, 16)     2320        ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 2000, 16)    64          ['conv1d_58[0][0]']
#  ormalization)
#
#  spatial_dropout1d_55 (SpatialD  (None, 2000, 16)    0           ['batch_normalization_55[0][0]']
#  ropout1D)
#
#  activation_55 (Activation)     (None, 2000, 16)     0           ['spatial_dropout1d_55[0][0]']
#
#  max_pooling1d_12 (MaxPooling1D  (None, 1000, 16)    0           ['activation_55[0][0]']
#  )
#
#  conv1d_59 (Conv1D)             (None, 1000, 32)     4640        ['max_pooling1d_12[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 1000, 32)    128         ['conv1d_59[0][0]']
#  ormalization)
#
#  spatial_dropout1d_56 (SpatialD  (None, 1000, 32)    0           ['batch_normalization_56[0][0]']
#  ropout1D)
#
#  activation_56 (Activation)     (None, 1000, 32)     0           ['spatial_dropout1d_56[0][0]']
#
#  conv1d_60 (Conv1D)             (None, 1000, 32)     9248        ['activation_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 1000, 32)    128         ['conv1d_60[0][0]']
#  ormalization)
#
#  spatial_dropout1d_57 (SpatialD  (None, 1000, 32)    0           ['batch_normalization_57[0][0]']
#  ropout1D)
#
#  activation_57 (Activation)     (None, 1000, 32)     0           ['spatial_dropout1d_57[0][0]']
#
#  max_pooling1d_13 (MaxPooling1D  (None, 500, 32)     0           ['activation_57[0][0]']
#  )
#
#  conv1d_61 (Conv1D)             (None, 500, 64)      18496       ['max_pooling1d_13[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 500, 64)     256         ['conv1d_61[0][0]']
#  ormalization)
#
#  spatial_dropout1d_58 (SpatialD  (None, 500, 64)     0           ['batch_normalization_58[0][0]']
#  ropout1D)
#
#  activation_58 (Activation)     (None, 500, 64)      0           ['spatial_dropout1d_58[0][0]']
#
#  conv1d_62 (Conv1D)             (None, 500, 64)      36928       ['activation_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 500, 64)     256         ['conv1d_62[0][0]']
#  ormalization)
#
#  spatial_dropout1d_59 (SpatialD  (None, 500, 64)     0           ['batch_normalization_59[0][0]']
#  ropout1D)
#
#  activation_59 (Activation)     (None, 500, 64)      0           ['spatial_dropout1d_59[0][0]']
#
#  max_pooling1d_14 (MaxPooling1D  (None, 250, 64)     0           ['activation_59[0][0]']
#  )
#
#  conv1d_63 (Conv1D)             (None, 250, 128)     73856       ['max_pooling1d_14[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 250, 128)    512         ['conv1d_63[0][0]']
#  ormalization)
#
#  spatial_dropout1d_60 (SpatialD  (None, 250, 128)    0           ['batch_normalization_60[0][0]']
#  ropout1D)
#
#  activation_60 (Activation)     (None, 250, 128)     0           ['spatial_dropout1d_60[0][0]']
#
#  conv1d_64 (Conv1D)             (None, 250, 128)     147584      ['activation_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 250, 128)    512         ['conv1d_64[0][0]']
#  ormalization)
#
#  spatial_dropout1d_61 (SpatialD  (None, 250, 128)    0           ['batch_normalization_61[0][0]']
#  ropout1D)
#
#  activation_61 (Activation)     (None, 250, 128)     0           ['spatial_dropout1d_61[0][0]']
#
#  max_pooling1d_15 (MaxPooling1D  (None, 125, 128)    0           ['activation_61[0][0]']
#  )
#
#  conv1d_65 (Conv1D)             (None, 125, 256)     295168      ['max_pooling1d_15[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 125, 256)    1024        ['conv1d_65[0][0]']
#  ormalization)
#
#  spatial_dropout1d_62 (SpatialD  (None, 125, 256)    0           ['batch_normalization_62[0][0]']
#  ropout1D)
#
#  activation_62 (Activation)     (None, 125, 256)     0           ['spatial_dropout1d_62[0][0]']
#
#  conv1d_66 (Conv1D)             (None, 125, 256)     590080      ['activation_62[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 125, 256)    1024        ['conv1d_66[0][0]']
#  ormalization)
#
#  spatial_dropout1d_63 (SpatialD  (None, 125, 256)    0           ['batch_normalization_63[0][0]']
#  ropout1D)
#
#  activation_63 (Activation)     (None, 125, 256)     0           ['spatial_dropout1d_63[0][0]']
#
#  conv1d_transpose_12 (Conv1DTra  (None, 250, 128)    262272      ['activation_63[0][0]']
#  nspose)
#
#  concatenate_12 (Concatenate)   (None, 250, 256)     0           ['conv1d_transpose_12[0][0]',
#                                                                   'activation_61[0][0]']
#
#  conv1d_67 (Conv1D)             (None, 250, 128)     295040      ['concatenate_12[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 250, 128)    512         ['conv1d_67[0][0]']
#  ormalization)
#
#  spatial_dropout1d_64 (SpatialD  (None, 250, 128)    0           ['batch_normalization_64[0][0]']
#  ropout1D)
#
#  activation_64 (Activation)     (None, 250, 128)     0           ['spatial_dropout1d_64[0][0]']
#
#  conv1d_68 (Conv1D)             (None, 250, 128)     147584      ['activation_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 250, 128)    512         ['conv1d_68[0][0]']
#  ormalization)
#
#  spatial_dropout1d_65 (SpatialD  (None, 250, 128)    0           ['batch_normalization_65[0][0]']
#  ropout1D)
#
#  activation_65 (Activation)     (None, 250, 128)     0           ['spatial_dropout1d_65[0][0]']
#
#  conv1d_transpose_13 (Conv1DTra  (None, 500, 64)     65600       ['activation_65[0][0]']
#  nspose)
#
#  concatenate_13 (Concatenate)   (None, 500, 128)     0           ['conv1d_transpose_13[0][0]',
#                                                                   'activation_59[0][0]']
#
#  conv1d_69 (Conv1D)             (None, 500, 64)      73792       ['concatenate_13[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 500, 64)     256         ['conv1d_69[0][0]']
#  ormalization)
#
#  spatial_dropout1d_66 (SpatialD  (None, 500, 64)     0           ['batch_normalization_66[0][0]']
#  ropout1D)
#
#  activation_66 (Activation)     (None, 500, 64)      0           ['spatial_dropout1d_66[0][0]']
#
#  conv1d_70 (Conv1D)             (None, 500, 64)      36928       ['activation_66[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 500, 64)     256         ['conv1d_70[0][0]']
#  ormalization)
#
#  spatial_dropout1d_67 (SpatialD  (None, 500, 64)     0           ['batch_normalization_67[0][0]']
#  ropout1D)
#
#  activation_67 (Activation)     (None, 500, 64)      0           ['spatial_dropout1d_67[0][0]']
#
#  conv1d_transpose_14 (Conv1DTra  (None, 1000, 32)    16416       ['activation_67[0][0]']
#  nspose)
#
#  concatenate_14 (Concatenate)   (None, 1000, 64)     0           ['conv1d_transpose_14[0][0]',
#                                                                   'activation_57[0][0]']
#
#  conv1d_71 (Conv1D)             (None, 1000, 32)     18464       ['concatenate_14[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 1000, 32)    128         ['conv1d_71[0][0]']
#  ormalization)
#
#  spatial_dropout1d_68 (SpatialD  (None, 1000, 32)    0           ['batch_normalization_68[0][0]']
#  ropout1D)
#
#  activation_68 (Activation)     (None, 1000, 32)     0           ['spatial_dropout1d_68[0][0]']
#
#  conv1d_72 (Conv1D)             (None, 1000, 32)     9248        ['activation_68[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 1000, 32)    128         ['conv1d_72[0][0]']
#  ormalization)
#
#  spatial_dropout1d_69 (SpatialD  (None, 1000, 32)    0           ['batch_normalization_69[0][0]']
#  ropout1D)
#
#  activation_69 (Activation)     (None, 1000, 32)     0           ['spatial_dropout1d_69[0][0]']
#
#  conv1d_transpose_15 (Conv1DTra  (None, 2000, 16)    4112        ['activation_69[0][0]']
#  nspose)
#
#  concatenate_15 (Concatenate)   (None, 2000, 32)     0           ['conv1d_transpose_15[0][0]',
#                                                                   'activation_55[0][0]']
#
#  conv1d_73 (Conv1D)             (None, 2000, 16)     4624        ['concatenate_15[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 2000, 16)    64          ['conv1d_73[0][0]']
#  ormalization)
#
#  spatial_dropout1d_70 (SpatialD  (None, 2000, 16)    0           ['batch_normalization_70[0][0]']
#  ropout1D)
#
#  activation_70 (Activation)     (None, 2000, 16)     0           ['spatial_dropout1d_70[0][0]']
#
#  conv1d_74 (Conv1D)             (None, 2000, 16)     2320        ['activation_70[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 2000, 16)    64          ['conv1d_74[0][0]']
#  ormalization)
#
#  spatial_dropout1d_71 (SpatialD  (None, 2000, 16)    0           ['batch_normalization_71[0][0]']
#  ropout1D)
#
#  activation_71 (Activation)     (None, 2000, 16)     0           ['spatial_dropout1d_71[0][0]']
#
#  conv1d_75 (Conv1D)             (None, 2000, 2)      34          ['activation_71[0][0]']
#
# ==================================================================================================
# Total params: 2,120,802
# Trainable params: 2,117,858
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
# 5. Train
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss='binary_crossentropy',
              metrics=['accuracy', f1_score])

callbacks_list = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="weights.h5",
        monitor="val_f1_score",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_f1_score",
        min_delta=0.005,
        mode="max",
        patience=10,
        verbose=1),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_f1_score',
        factor=0.5,
        patience=5,
        mode='max',
        min_delta=0.01,
        cooldown=0,
        min_lr=0.0001,
        verbose=1)
]

history = model.fit(train[0], train[1],
                    validation_data=(valid[0], valid[1]),
                    callbacks=callbacks_list,
                    epochs=epochs,
                    batch_size=batch_size,
                    shuffle=True,
                    )


loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
# f1 = history.history["f1_score"]
# val_f1 = history.history["val_f1_score"]

epochs_range = range(len(loss))
fig, ax = plt.subplots(1, 3, figsize = (20, 12))
ax[0].plot(epochs_range, loss, label='Training Loss')
ax[0].plot(epochs_range, val_loss, label='Validation Loss')

ax[1].plot(epochs_range, accuracy, label='Training Accuracy')
ax[1].plot(epochs_range, val_acc, label='Validation Accuracy')

# ax[2].plot(epochs_range, f1, label='Training f1-score')
# ax[2].plot(epochs_range, val_f1, label='Validation f1-score')
plt.show()

del model, history, train
# Out:
# Epoch 1/200
# 4/4 [==============================] - ETA: 0s - loss: 0.6361 - accuracy: 0.4095 - f1_score: 0.5571
# Epoch 1: val_f1_score improved from -inf to 0.56120, saving model to weights.h5
# 4/4 [==============================] - 25s 2s/step - loss: 0.6361 - accuracy: 0.4095 - f1_score: 0.5571 - val_loss: 3844.3999 - val_accuracy: 0.0010 - val_f1_score: 0.5612 - lr: 0.0050
# Epoch 2/200
# 4/4 [==============================] - ETA: 0s - loss: 0.3606 - accuracy: 0.4639 - f1_score: 0.5589
# Epoch 2: val_f1_score did not improve from 0.56120
# 4/4 [==============================] - 2s 389ms/step - loss: 0.3606 - accuracy: 0.4639 - f1_score: 0.5589 - val_loss: 67584.7891 - val_accuracy: 0.2470 - val_f1_score: 0.5612 - lr: 0.0050
# Epoch 3/200
# 4/4 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.4937 - f1_score: 0.5579
# Epoch 3: val_f1_score did not improve from 0.56120
# 4/4 [==============================] - 2s 378ms/step - loss: 0.3029 - accuracy: 0.4937 - f1_score: 0.5579 - val_loss: 277275.9375 - val_accuracy: 0.0000e+00 - val_f1_score: 0.5612 - lr: 0.0050
# Epoch 4/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.4841 - f1_score: 0.5583
# Epoch 4: val_f1_score did not improve from 0.56120
# 4/4 [==============================] - 2s 376ms/step - loss: 0.2620 - accuracy: 0.4841 - f1_score: 0.5583 - val_loss: 326039.2500 - val_accuracy: 0.0000e+00 - val_f1_score: 0.5612 - lr: 0.0050
# Epoch 5/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.4793 - f1_score: 0.5583
# Epoch 5: val_f1_score did not improve from 0.56120
# 4/4 [==============================] - 2s 376ms/step - loss: 0.2278 - accuracy: 0.4793 - f1_score: 0.5583 - val_loss: 113059.7734 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5612 - lr: 0.0050
# Epoch 6/200
# 4/4 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.5094 - f1_score: 0.5573
# Epoch 6: val_f1_score did not improve from 0.56120
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 4/4 [==============================] - 2s 407ms/step - loss: 0.2030 - accuracy: 0.5094 - f1_score: 0.5573 - val_loss: 123751.9766 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5612 - lr: 0.0050
# Epoch 7/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.4977 - f1_score: 0.5587
# Epoch 7: val_f1_score did not improve from 0.56120
# 4/4 [==============================] - 2s 407ms/step - loss: 0.1784 - accuracy: 0.4977 - f1_score: 0.5587 - val_loss: 57708.1992 - val_accuracy: 0.0000e+00 - val_f1_score: 0.5612 - lr: 0.0025
# Epoch 8/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.4928 - f1_score: 0.5586
# Epoch 8: val_f1_score did not improve from 0.56120
# 4/4 [==============================] - 2s 385ms/step - loss: 0.1654 - accuracy: 0.4928 - f1_score: 0.5586 - val_loss: 22595.4336 - val_accuracy: 0.0000e+00 - val_f1_score: 0.5612 - lr: 0.0025
# Epoch 9/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.4988 - f1_score: 0.5586
# Epoch 9: val_f1_score did not improve from 0.56120
# 4/4 [==============================] - 2s 389ms/step - loss: 0.1559 - accuracy: 0.4988 - f1_score: 0.5586 - val_loss: 6066.0674 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5612 - lr: 0.0025
# Epoch 10/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.5141 - f1_score: 0.5574
# Epoch 10: val_f1_score did not improve from 0.56120
# 4/4 [==============================] - 2s 374ms/step - loss: 0.1418 - accuracy: 0.5141 - f1_score: 0.5574 - val_loss: 1318.4298 - val_accuracy: 0.0010 - val_f1_score: 0.5612 - lr: 0.0025
# Epoch 11/200
# 4/4 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.5009 - f1_score: 0.5579
# Epoch 11: val_f1_score did not improve from 0.56120
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 4/4 [==============================] - 2s 375ms/step - loss: 0.1329 - accuracy: 0.5009 - f1_score: 0.5579 - val_loss: 573.5456 - val_accuracy: 0.0010 - val_f1_score: 0.5612 - lr: 0.0025
# Epoch 11: early stopping

# %%
# valid = [np.load("valid_x.npy"), np.load("valid_y.npy")]
# print(valid[0].shape)

# Predict(test=valid)
# Out:
# (217, 2000, 1)
# (None, 250, 128) (None, 250, 128)
# (None, 500, 64) (None, 500, 64)
# (None, 1000, 32) (None, 1000, 32)
# (None, 2000, 16) (None, 2000, 16)
# 1/1 [==============================] - 1s 1s/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-074d3b6d7965> in <cell line: 4>()
#       2 print(valid[0].shape)
#       3
# ----> 4 Predict(test=valid)
#
# <ipython-input-17-d71e00bcca6e> in Predict(test, n_sample)
#      19         fig, ax = plt.subplots(3, 1, figsize=(20, 12))
#      20
# ---> 21         ax[0].plot(test_ecg[:, 1])
#      22         ax[0].set_title(f"ECG_{i}'s lead II", fontsize=10)
#      23
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
img_weekday = weekday.iloc[:,[2,3]]
img_weekday["Duration (hr)"] = img_weekday["Duration (hr)"].astype('float') * 1000
img_weekday['Value']= img_weekday['Value'].replace('Core',1)
img_weekday['Value']= img_weekday['Value'].replace('REM',0)
img_weekday['Value']= img_weekday['Value'].replace('Deep',0)
img_weekday['Value']= img_weekday['Value'].replace('Awake',0)
img_weekday = img_weekday[["Duration (hr)", "Value"]]
img_weekday = np.array(img_weekday)

x_list = []   # 라벨을 duration 만큼 반복한 array를 list에 append
for x in img_weekday:
  if x[1] != 0:
    timeseries = np.ones([int(x[0])]) * x[1]
    x_list.append(timeseries)
  else:
    timeseries = np.zeros([int(x[0])]) * x[1]
    x_list.append(timeseries)

ts = np.concatenate(x_list)[:-3383]   # 7567로 나누어떨어지기 위해 데이터 버림.
print(ts.shape)
ts
tmp = ts.reshape(50, 7500, -1)
print(tmp.shape)
# Out:
# (375000,)
# (50, 7500, 1)

# %%
# Augmentation
augmentation(tmp)
del tmp
# Out:
# Start Augmentation
# Number of Train set : 870
# Number of Valid set : 217
#
# Start saving the dataset...
# Complete saving

# %%
# 데이터 로드
train = [np.load("train_x.npy"), np.load("train_y.npy")]
valid = [np.load("valid_x.npy"), np.load("valid_y.npy")]

# %%
# 4. Model
print("Start Training")
batch_size = 256
lr = 0.005
epochs = 2000

model = UNet1D()
model.summary()
# Out:
# Start Training
# (None, 250, 128) (None, 250, 128)
# (None, 500, 64) (None, 500, 64)
# (None, 1000, 32) (None, 1000, 32)
# (None, 2000, 16) (None, 2000, 16)
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 2000, 1)]    0           []
#
#  conv1d_95 (Conv1D)             (None, 2000, 16)     160         ['input_6[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 2000, 16)    64          ['conv1d_95[0][0]']
#  ormalization)
#
#  spatial_dropout1d_90 (SpatialD  (None, 2000, 16)    0           ['batch_normalization_90[0][0]']
#  ropout1D)
#
#  activation_90 (Activation)     (None, 2000, 16)     0           ['spatial_dropout1d_90[0][0]']
#
#  conv1d_96 (Conv1D)             (None, 2000, 16)     2320        ['activation_90[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 2000, 16)    64          ['conv1d_96[0][0]']
#  ormalization)
#
#  spatial_dropout1d_91 (SpatialD  (None, 2000, 16)    0           ['batch_normalization_91[0][0]']
#  ropout1D)
#
#  activation_91 (Activation)     (None, 2000, 16)     0           ['spatial_dropout1d_91[0][0]']
#
#  max_pooling1d_20 (MaxPooling1D  (None, 1000, 16)    0           ['activation_91[0][0]']
#  )
#
#  conv1d_97 (Conv1D)             (None, 1000, 32)     4640        ['max_pooling1d_20[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 1000, 32)    128         ['conv1d_97[0][0]']
#  ormalization)
#
#  spatial_dropout1d_92 (SpatialD  (None, 1000, 32)    0           ['batch_normalization_92[0][0]']
#  ropout1D)
#
#  activation_92 (Activation)     (None, 1000, 32)     0           ['spatial_dropout1d_92[0][0]']
#
#  conv1d_98 (Conv1D)             (None, 1000, 32)     9248        ['activation_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 1000, 32)    128         ['conv1d_98[0][0]']
#  ormalization)
#
#  spatial_dropout1d_93 (SpatialD  (None, 1000, 32)    0           ['batch_normalization_93[0][0]']
#  ropout1D)
#
#  activation_93 (Activation)     (None, 1000, 32)     0           ['spatial_dropout1d_93[0][0]']
#
#  max_pooling1d_21 (MaxPooling1D  (None, 500, 32)     0           ['activation_93[0][0]']
#  )
#
#  conv1d_99 (Conv1D)             (None, 500, 64)      18496       ['max_pooling1d_21[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 500, 64)     256         ['conv1d_99[0][0]']
#  ormalization)
#
#  spatial_dropout1d_94 (SpatialD  (None, 500, 64)     0           ['batch_normalization_94[0][0]']
#  ropout1D)
#
#  activation_94 (Activation)     (None, 500, 64)      0           ['spatial_dropout1d_94[0][0]']
#
#  conv1d_100 (Conv1D)            (None, 500, 64)      36928       ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 500, 64)     256         ['conv1d_100[0][0]']
#  ormalization)
#
#  spatial_dropout1d_95 (SpatialD  (None, 500, 64)     0           ['batch_normalization_95[0][0]']
#  ropout1D)
#
#  activation_95 (Activation)     (None, 500, 64)      0           ['spatial_dropout1d_95[0][0]']
#
#  max_pooling1d_22 (MaxPooling1D  (None, 250, 64)     0           ['activation_95[0][0]']
#  )
#
#  conv1d_101 (Conv1D)            (None, 250, 128)     73856       ['max_pooling1d_22[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 250, 128)    512         ['conv1d_101[0][0]']
#  ormalization)
#
#  spatial_dropout1d_96 (SpatialD  (None, 250, 128)    0           ['batch_normalization_96[0][0]']
#  ropout1D)
#
#  activation_96 (Activation)     (None, 250, 128)     0           ['spatial_dropout1d_96[0][0]']
#
#  conv1d_102 (Conv1D)            (None, 250, 128)     147584      ['activation_96[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 250, 128)    512         ['conv1d_102[0][0]']
#  ormalization)
#
#  spatial_dropout1d_97 (SpatialD  (None, 250, 128)    0           ['batch_normalization_97[0][0]']
#  ropout1D)
#
#  activation_97 (Activation)     (None, 250, 128)     0           ['spatial_dropout1d_97[0][0]']
#
#  max_pooling1d_23 (MaxPooling1D  (None, 125, 128)    0           ['activation_97[0][0]']
#  )
#
#  conv1d_103 (Conv1D)            (None, 125, 256)     295168      ['max_pooling1d_23[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 125, 256)    1024        ['conv1d_103[0][0]']
#  ormalization)
#
#  spatial_dropout1d_98 (SpatialD  (None, 125, 256)    0           ['batch_normalization_98[0][0]']
#  ropout1D)
#
#  activation_98 (Activation)     (None, 125, 256)     0           ['spatial_dropout1d_98[0][0]']
#
#  conv1d_104 (Conv1D)            (None, 125, 256)     590080      ['activation_98[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 125, 256)    1024        ['conv1d_104[0][0]']
#  ormalization)
#
#  spatial_dropout1d_99 (SpatialD  (None, 125, 256)    0           ['batch_normalization_99[0][0]']
#  ropout1D)
#
#  activation_99 (Activation)     (None, 125, 256)     0           ['spatial_dropout1d_99[0][0]']
#
#  conv1d_transpose_20 (Conv1DTra  (None, 250, 128)    262272      ['activation_99[0][0]']
#  nspose)
#
#  concatenate_20 (Concatenate)   (None, 250, 256)     0           ['conv1d_transpose_20[0][0]',
#                                                                   'activation_97[0][0]']
#
#  conv1d_105 (Conv1D)            (None, 250, 128)     295040      ['concatenate_20[0][0]']
#
#  batch_normalization_100 (Batch  (None, 250, 128)    512         ['conv1d_105[0][0]']
#  Normalization)
#
#  spatial_dropout1d_100 (Spatial  (None, 250, 128)    0           ['batch_normalization_100[0][0]']
#  Dropout1D)
#
#  activation_100 (Activation)    (None, 250, 128)     0           ['spatial_dropout1d_100[0][0]']
#
#  conv1d_106 (Conv1D)            (None, 250, 128)     147584      ['activation_100[0][0]']
#
#  batch_normalization_101 (Batch  (None, 250, 128)    512         ['conv1d_106[0][0]']
#  Normalization)
#
#  spatial_dropout1d_101 (Spatial  (None, 250, 128)    0           ['batch_normalization_101[0][0]']
#  Dropout1D)
#
#  activation_101 (Activation)    (None, 250, 128)     0           ['spatial_dropout1d_101[0][0]']
#
#  conv1d_transpose_21 (Conv1DTra  (None, 500, 64)     65600       ['activation_101[0][0]']
#  nspose)
#
#  concatenate_21 (Concatenate)   (None, 500, 128)     0           ['conv1d_transpose_21[0][0]',
#                                                                   'activation_95[0][0]']
#
#  conv1d_107 (Conv1D)            (None, 500, 64)      73792       ['concatenate_21[0][0]']
#
#  batch_normalization_102 (Batch  (None, 500, 64)     256         ['conv1d_107[0][0]']
#  Normalization)
#
#  spatial_dropout1d_102 (Spatial  (None, 500, 64)     0           ['batch_normalization_102[0][0]']
#  Dropout1D)
#
#  activation_102 (Activation)    (None, 500, 64)      0           ['spatial_dropout1d_102[0][0]']
#
#  conv1d_108 (Conv1D)            (None, 500, 64)      36928       ['activation_102[0][0]']
#
#  batch_normalization_103 (Batch  (None, 500, 64)     256         ['conv1d_108[0][0]']
#  Normalization)
#
#  spatial_dropout1d_103 (Spatial  (None, 500, 64)     0           ['batch_normalization_103[0][0]']
#  Dropout1D)
#
#  activation_103 (Activation)    (None, 500, 64)      0           ['spatial_dropout1d_103[0][0]']
#
#  conv1d_transpose_22 (Conv1DTra  (None, 1000, 32)    16416       ['activation_103[0][0]']
#  nspose)
#
#  concatenate_22 (Concatenate)   (None, 1000, 64)     0           ['conv1d_transpose_22[0][0]',
#                                                                   'activation_93[0][0]']
#
#  conv1d_109 (Conv1D)            (None, 1000, 32)     18464       ['concatenate_22[0][0]']
#
#  batch_normalization_104 (Batch  (None, 1000, 32)    128         ['conv1d_109[0][0]']
#  Normalization)
#
#  spatial_dropout1d_104 (Spatial  (None, 1000, 32)    0           ['batch_normalization_104[0][0]']
#  Dropout1D)
#
#  activation_104 (Activation)    (None, 1000, 32)     0           ['spatial_dropout1d_104[0][0]']
#
#  conv1d_110 (Conv1D)            (None, 1000, 32)     9248        ['activation_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 1000, 32)    128         ['conv1d_110[0][0]']
#  Normalization)
#
#  spatial_dropout1d_105 (Spatial  (None, 1000, 32)    0           ['batch_normalization_105[0][0]']
#  Dropout1D)
#
#  activation_105 (Activation)    (None, 1000, 32)     0           ['spatial_dropout1d_105[0][0]']
#
#  conv1d_transpose_23 (Conv1DTra  (None, 2000, 16)    4112        ['activation_105[0][0]']
#  nspose)
#
#  concatenate_23 (Concatenate)   (None, 2000, 32)     0           ['conv1d_transpose_23[0][0]',
#                                                                   'activation_91[0][0]']
#
#  conv1d_111 (Conv1D)            (None, 2000, 16)     4624        ['concatenate_23[0][0]']
#
#  batch_normalization_106 (Batch  (None, 2000, 16)    64          ['conv1d_111[0][0]']
#  Normalization)
#
#  spatial_dropout1d_106 (Spatial  (None, 2000, 16)    0           ['batch_normalization_106[0][0]']
#  Dropout1D)
#
#  activation_106 (Activation)    (None, 2000, 16)     0           ['spatial_dropout1d_106[0][0]']
#
#  conv1d_112 (Conv1D)            (None, 2000, 16)     2320        ['activation_106[0][0]']
#
#  batch_normalization_107 (Batch  (None, 2000, 16)    64          ['conv1d_112[0][0]']
#  Normalization)
#
#  spatial_dropout1d_107 (Spatial  (None, 2000, 16)    0           ['batch_normalization_107[0][0]']
#  Dropout1D)
#
#  activation_107 (Activation)    (None, 2000, 16)     0           ['spatial_dropout1d_107[0][0]']
#
#  conv1d_113 (Conv1D)            (None, 2000, 2)      34          ['activation_107[0][0]']
#
# ==================================================================================================
# Total params: 2,120,802
# Trainable params: 2,117,858
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
# 5. Train
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss='binary_crossentropy',
              metrics=['accuracy', f1_score])

callbacks_list = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="weights.h5",
        monitor="val_f1_score",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_f1_score",
        min_delta=0.005,
        mode="max",
        patience=10,
        verbose=1),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_f1_score',
        factor=0.5,
        patience=5,
        mode='max',
        min_delta=0.01,
        cooldown=0,
        min_lr=0.0001,
        verbose=1)
]

history = model.fit(train[0], train[1],
                    validation_data=(valid[0], valid[1]),
                    callbacks=callbacks_list,
                    epochs=epochs,
                    batch_size=batch_size,
                    shuffle=True,
                    )


loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
f1 = history.history["f1_score"]
val_f1 = history.history["val_f1_score"]

epochs_range = range(len(loss))
fig, ax = plt.subplots(1, 3, figsize = (20, 12))
ax[0].plot(epochs_range, loss, label='Training Loss')
ax[0].plot(epochs_range, val_loss, label='Validation Loss')

ax[1].plot(epochs_range, accuracy, label='Training Accuracy')
ax[1].plot(epochs_range, val_acc, label='Validation Accuracy')

ax[2].plot(epochs_range, f1, label='Training f1-score')
ax[2].plot(epochs_range, val_f1, label='Validation f1-score')
plt.show()

del model, history, train
# Out:
# Epoch 1/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.6338 - accuracy: 0.1556 - f1_score: 0.5555
# Epoch 1: val_f1_score improved from -inf to 0.56928, saving model to weights.h5
# 4/4 [==============================] - 24s 1s/step - loss: 0.6338 - accuracy: 0.1556 - f1_score: 0.5555 - val_loss: 167.8443 - val_accuracy: 0.0000e+00 - val_f1_score: 0.5693 - lr: 0.0050
# Epoch 2/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.3382 - accuracy: 0.1360 - f1_score: 0.5563
# Epoch 2: val_f1_score did not improve from 0.56928
# 4/4 [==============================] - 2s 395ms/step - loss: 0.3382 - accuracy: 0.1360 - f1_score: 0.5563 - val_loss: 2466.6714 - val_accuracy: 0.0010 - val_f1_score: 0.5693 - lr: 0.0050
# Epoch 3/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.2583 - accuracy: 0.1682 - f1_score: 0.5575
# Epoch 3: val_f1_score did not improve from 0.56928
# 4/4 [==============================] - 2s 389ms/step - loss: 0.2583 - accuracy: 0.1682 - f1_score: 0.5575 - val_loss: 4149.8394 - val_accuracy: 0.0000e+00 - val_f1_score: 0.5693 - lr: 0.0050
# Epoch 4/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.1981 - f1_score: 0.5571
# Epoch 4: val_f1_score did not improve from 0.56928
# 4/4 [==============================] - 2s 372ms/step - loss: 0.2157 - accuracy: 0.1981 - f1_score: 0.5571 - val_loss: 10650.2100 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5693 - lr: 0.0050
# Epoch 5/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.2289 - f1_score: 0.5559
# Epoch 5: val_f1_score did not improve from 0.56928
# 4/4 [==============================] - 2s 398ms/step - loss: 0.1812 - accuracy: 0.2289 - f1_score: 0.5559 - val_loss: 12953.6885 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5693 - lr: 0.0050
# Epoch 6/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.2743 - f1_score: 0.5574
# Epoch 6: val_f1_score did not improve from 0.56928
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 4/4 [==============================] - 2s 392ms/step - loss: 0.1530 - accuracy: 0.2743 - f1_score: 0.5574 - val_loss: 4534.8213 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5693 - lr: 0.0050
# Epoch 7/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.2602 - f1_score: 0.5566
# Epoch 7: val_f1_score did not improve from 0.56928
# 4/4 [==============================] - 2s 378ms/step - loss: 0.1354 - accuracy: 0.2602 - f1_score: 0.5566 - val_loss: 1503.2445 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5693 - lr: 0.0025
# Epoch 8/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.2521 - f1_score: 0.5557
# Epoch 8: val_f1_score did not improve from 0.56928
# 4/4 [==============================] - 2s 407ms/step - loss: 0.1248 - accuracy: 0.2521 - f1_score: 0.5557 - val_loss: 784.7792 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5693 - lr: 0.0025
# Epoch 9/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.2733 - f1_score: 0.5572
# Epoch 9: val_f1_score did not improve from 0.56928
# 4/4 [==============================] - 2s 388ms/step - loss: 0.1136 - accuracy: 0.2733 - f1_score: 0.5572 - val_loss: 568.9807 - val_accuracy: 5.0000e-04 - val_f1_score: 0.5693 - lr: 0.0025
# Epoch 10/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.2665 - f1_score: 0.5578
# Epoch 10: val_f1_score did not improve from 0.56928
# 4/4 [==============================] - 2s 405ms/step - loss: 0.1103 - accuracy: 0.2665 - f1_score: 0.5578 - val_loss: 392.9796 - val_accuracy: 0.0027 - val_f1_score: 0.5693 - lr: 0.0025
# Epoch 11/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.2742 - f1_score: 0.5564
# Epoch 11: val_f1_score did not improve from 0.56928
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 4/4 [==============================] - 2s 406ms/step - loss: 0.0998 - accuracy: 0.2742 - f1_score: 0.5564 - val_loss: 184.9017 - val_accuracy: 0.0205 - val_f1_score: 0.5693 - lr: 0.0025
# Epoch 11: early stopping

# %%
img_weekday = weekday.iloc[:,[2,3]]
img_weekday["Duration (hr)"] = img_weekday["Duration (hr)"].astype('float') * 1000
img_weekday['Value']= img_weekday['Value'].replace('Core',1)
img_weekday['Value']= img_weekday['Value'].replace('REM',0)
img_weekday['Value']= img_weekday['Value'].replace('Deep',0)
img_weekday['Value']= img_weekday['Value'].replace('Awake',0)
img_weekday = img_weekday[["Duration (hr)", "Value"]]
img_weekday = np.array(img_weekday)

x_list = []   # 라벨을 duration 만큼 반복한 array를 list에 append
for x in img_weekday:
  if x[1] != 0:
    timeseries = np.ones([int(x[0])]) * x[1]
    x_list.append(timeseries)
  else:
    timeseries = np.zeros([int(x[0])]) * x[1]
    x_list.append(timeseries)

ts = np.concatenate(x_list)[:-3383]   # 7567로 나누어떨어지기 위해 데이터 버림.
print(ts.shape)
ts
tmp = ts.reshape(50, 7500, -1)
print(tmp.shape)

# Augmentation
augmentation(tmp)
del tmp

# 데이터 로드
train = [np.load("train_x.npy"), np.load("train_y.npy")]
valid = [np.load("valid_x.npy"), np.load("valid_y.npy")]
# Out:
# (375000,)
# (50, 7500, 1)
# Start Augmentation
# Number of Train set : 870
# Number of Valid set : 217
#
# Start saving the dataset...
# Complete saving

# %%
# 4. Model
print("Start Training")
batch_size = 256
lr = 0.005
epochs = 2000

model = UNet1D()
model.summary()

# 5. Train
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss='binary_crossentropy',
              metrics=['accuracy', f1_score])

callbacks_list = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="weights.h5",
        monitor="val_f1_score",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_f1_score",
        min_delta=0.005,
        mode="max",
        patience=10,
        verbose=1),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_f1_score',
        factor=0.5,
        patience=5,
        mode='max',
        min_delta=0.01,
        cooldown=0,
        min_lr=0.0001,
        verbose=1)
]

history = model.fit(train[0], train[1],
                    validation_data=(valid[0], valid[1]),
                    callbacks=callbacks_list,
                    epochs=epochs,
                    batch_size=batch_size,
                    shuffle=True,
                    )


loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
f1 = history.history["f1_score"]
val_f1 = history.history["val_f1_score"]

epochs_range = range(len(loss))
fig, ax = plt.subplots(1, 3, figsize = (20, 12))
ax[0].plot(epochs_range, loss, label='Training Loss')
ax[0].plot(epochs_range, val_loss, label='Validation Loss')

ax[1].plot(epochs_range, accuracy, label='Training Accuracy')
ax[1].plot(epochs_range, val_acc, label='Validation Accuracy')

ax[2].plot(epochs_range, f1, label='Training f1-score')
ax[2].plot(epochs_range, val_f1, label='Validation f1-score')
plt.show()

del model, history, train
# Out:
# Start Training
# (None, 250, 128) (None, 250, 128)
# (None, 500, 64) (None, 500, 64)
# (None, 1000, 32) (None, 1000, 32)
# (None, 2000, 16) (None, 2000, 16)
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 2000, 1)]    0           []
#
#  conv1d_114 (Conv1D)            (None, 2000, 16)     160         ['input_7[0][0]']
#
#  batch_normalization_108 (Batch  (None, 2000, 16)    64          ['conv1d_114[0][0]']
#  Normalization)
#
#  spatial_dropout1d_108 (Spatial  (None, 2000, 16)    0           ['batch_normalization_108[0][0]']
#  Dropout1D)
#
#  activation_108 (Activation)    (None, 2000, 16)     0           ['spatial_dropout1d_108[0][0]']
#
#  conv1d_115 (Conv1D)            (None, 2000, 16)     2320        ['activation_108[0][0]']
#
#  batch_normalization_109 (Batch  (None, 2000, 16)    64          ['conv1d_115[0][0]']
#  Normalization)
#
#  spatial_dropout1d_109 (Spatial  (None, 2000, 16)    0           ['batch_normalization_109[0][0]']
#  Dropout1D)
#
#  activation_109 (Activation)    (None, 2000, 16)     0           ['spatial_dropout1d_109[0][0]']
#
#  max_pooling1d_24 (MaxPooling1D  (None, 1000, 16)    0           ['activation_109[0][0]']
#  )
#
#  conv1d_116 (Conv1D)            (None, 1000, 32)     4640        ['max_pooling1d_24[0][0]']
#
#  batch_normalization_110 (Batch  (None, 1000, 32)    128         ['conv1d_116[0][0]']
#  Normalization)
#
#  spatial_dropout1d_110 (Spatial  (None, 1000, 32)    0           ['batch_normalization_110[0][0]']
#  Dropout1D)
#
#  activation_110 (Activation)    (None, 1000, 32)     0           ['spatial_dropout1d_110[0][0]']
#
#  conv1d_117 (Conv1D)            (None, 1000, 32)     9248        ['activation_110[0][0]']
#
#  batch_normalization_111 (Batch  (None, 1000, 32)    128         ['conv1d_117[0][0]']
#  Normalization)
#
#  spatial_dropout1d_111 (Spatial  (None, 1000, 32)    0           ['batch_normalization_111[0][0]']
#  Dropout1D)
#
#  activation_111 (Activation)    (None, 1000, 32)     0           ['spatial_dropout1d_111[0][0]']
#
#  max_pooling1d_25 (MaxPooling1D  (None, 500, 32)     0           ['activation_111[0][0]']
#  )
#
#  conv1d_118 (Conv1D)            (None, 500, 64)      18496       ['max_pooling1d_25[0][0]']
#
#  batch_normalization_112 (Batch  (None, 500, 64)     256         ['conv1d_118[0][0]']
#  Normalization)
#
#  spatial_dropout1d_112 (Spatial  (None, 500, 64)     0           ['batch_normalization_112[0][0]']
#  Dropout1D)
#
#  activation_112 (Activation)    (None, 500, 64)      0           ['spatial_dropout1d_112[0][0]']
#
#  conv1d_119 (Conv1D)            (None, 500, 64)      36928       ['activation_112[0][0]']
#
#  batch_normalization_113 (Batch  (None, 500, 64)     256         ['conv1d_119[0][0]']
#  Normalization)
#
#  spatial_dropout1d_113 (Spatial  (None, 500, 64)     0           ['batch_normalization_113[0][0]']
#  Dropout1D)
#
#  activation_113 (Activation)    (None, 500, 64)      0           ['spatial_dropout1d_113[0][0]']
#
#  max_pooling1d_26 (MaxPooling1D  (None, 250, 64)     0           ['activation_113[0][0]']
#  )
#
#  conv1d_120 (Conv1D)            (None, 250, 128)     73856       ['max_pooling1d_26[0][0]']
#
#  batch_normalization_114 (Batch  (None, 250, 128)    512         ['conv1d_120[0][0]']
#  Normalization)
#
#  spatial_dropout1d_114 (Spatial  (None, 250, 128)    0           ['batch_normalization_114[0][0]']
#  Dropout1D)
#
#  activation_114 (Activation)    (None, 250, 128)     0           ['spatial_dropout1d_114[0][0]']
#
#  conv1d_121 (Conv1D)            (None, 250, 128)     147584      ['activation_114[0][0]']
#
#  batch_normalization_115 (Batch  (None, 250, 128)    512         ['conv1d_121[0][0]']
#  Normalization)
#
#  spatial_dropout1d_115 (Spatial  (None, 250, 128)    0           ['batch_normalization_115[0][0]']
#  Dropout1D)
#
#  activation_115 (Activation)    (None, 250, 128)     0           ['spatial_dropout1d_115[0][0]']
#
#  max_pooling1d_27 (MaxPooling1D  (None, 125, 128)    0           ['activation_115[0][0]']
#  )
#
#  conv1d_122 (Conv1D)            (None, 125, 256)     295168      ['max_pooling1d_27[0][0]']
#
#  batch_normalization_116 (Batch  (None, 125, 256)    1024        ['conv1d_122[0][0]']
#  Normalization)
#
#  spatial_dropout1d_116 (Spatial  (None, 125, 256)    0           ['batch_normalization_116[0][0]']
#  Dropout1D)
#
#  activation_116 (Activation)    (None, 125, 256)     0           ['spatial_dropout1d_116[0][0]']
#
#  conv1d_123 (Conv1D)            (None, 125, 256)     590080      ['activation_116[0][0]']
#
#  batch_normalization_117 (Batch  (None, 125, 256)    1024        ['conv1d_123[0][0]']
#  Normalization)
#
#  spatial_dropout1d_117 (Spatial  (None, 125, 256)    0           ['batch_normalization_117[0][0]']
#  Dropout1D)
#
#  activation_117 (Activation)    (None, 125, 256)     0           ['spatial_dropout1d_117[0][0]']
#
#  conv1d_transpose_24 (Conv1DTra  (None, 250, 128)    262272      ['activation_117[0][0]']
#  nspose)
#
#  concatenate_24 (Concatenate)   (None, 250, 256)     0           ['conv1d_transpose_24[0][0]',
#                                                                   'activation_115[0][0]']
#
#  conv1d_124 (Conv1D)            (None, 250, 128)     295040      ['concatenate_24[0][0]']
#
#  batch_normalization_118 (Batch  (None, 250, 128)    512         ['conv1d_124[0][0]']
#  Normalization)
#
#  spatial_dropout1d_118 (Spatial  (None, 250, 128)    0           ['batch_normalization_118[0][0]']
#  Dropout1D)
#
#  activation_118 (Activation)    (None, 250, 128)     0           ['spatial_dropout1d_118[0][0]']
#
#  conv1d_125 (Conv1D)            (None, 250, 128)     147584      ['activation_118[0][0]']
#
#  batch_normalization_119 (Batch  (None, 250, 128)    512         ['conv1d_125[0][0]']
#  Normalization)
#
#  spatial_dropout1d_119 (Spatial  (None, 250, 128)    0           ['batch_normalization_119[0][0]']
#  Dropout1D)
#
#  activation_119 (Activation)    (None, 250, 128)     0           ['spatial_dropout1d_119[0][0]']
#
#  conv1d_transpose_25 (Conv1DTra  (None, 500, 64)     65600       ['activation_119[0][0]']
#  nspose)
#
#  concatenate_25 (Concatenate)   (None, 500, 128)     0           ['conv1d_transpose_25[0][0]',
#                                                                   'activation_113[0][0]']
#
#  conv1d_126 (Conv1D)            (None, 500, 64)      73792       ['concatenate_25[0][0]']
#
#  batch_normalization_120 (Batch  (None, 500, 64)     256         ['conv1d_126[0][0]']
#  Normalization)
#
#  spatial_dropout1d_120 (Spatial  (None, 500, 64)     0           ['batch_normalization_120[0][0]']
#  Dropout1D)
#
#  activation_120 (Activation)    (None, 500, 64)      0           ['spatial_dropout1d_120[0][0]']
#
#  conv1d_127 (Conv1D)            (None, 500, 64)      36928       ['activation_120[0][0]']
#
#  batch_normalization_121 (Batch  (None, 500, 64)     256         ['conv1d_127[0][0]']
#  Normalization)
#
#  spatial_dropout1d_121 (Spatial  (None, 500, 64)     0           ['batch_normalization_121[0][0]']
#  Dropout1D)
#
#  activation_121 (Activation)    (None, 500, 64)      0           ['spatial_dropout1d_121[0][0]']
#
#  conv1d_transpose_26 (Conv1DTra  (None, 1000, 32)    16416       ['activation_121[0][0]']
#  nspose)
#
#  concatenate_26 (Concatenate)   (None, 1000, 64)     0           ['conv1d_transpose_26[0][0]',
#                                                                   'activation_111[0][0]']
#
#  conv1d_128 (Conv1D)            (None, 1000, 32)     18464       ['concatenate_26[0][0]']
#
#  batch_normalization_122 (Batch  (None, 1000, 32)    128         ['conv1d_128[0][0]']
#  Normalization)
#
#  spatial_dropout1d_122 (Spatial  (None, 1000, 32)    0           ['batch_normalization_122[0][0]']
#  Dropout1D)
#
#  activation_122 (Activation)    (None, 1000, 32)     0           ['spatial_dropout1d_122[0][0]']
#
#  conv1d_129 (Conv1D)            (None, 1000, 32)     9248        ['activation_122[0][0]']
#
#  batch_normalization_123 (Batch  (None, 1000, 32)    128         ['conv1d_129[0][0]']
#  Normalization)
#
#  spatial_dropout1d_123 (Spatial  (None, 1000, 32)    0           ['batch_normalization_123[0][0]']
#  Dropout1D)
#
#  activation_123 (Activation)    (None, 1000, 32)     0           ['spatial_dropout1d_123[0][0]']
#
#  conv1d_transpose_27 (Conv1DTra  (None, 2000, 16)    4112        ['activation_123[0][0]']
#  nspose)
#
#  concatenate_27 (Concatenate)   (None, 2000, 32)     0           ['conv1d_transpose_27[0][0]',
#                                                                   'activation_109[0][0]']
#
#  conv1d_130 (Conv1D)            (None, 2000, 16)     4624        ['concatenate_27[0][0]']
#
#  batch_normalization_124 (Batch  (None, 2000, 16)    64          ['conv1d_130[0][0]']
#  Normalization)
#
#  spatial_dropout1d_124 (Spatial  (None, 2000, 16)    0           ['batch_normalization_124[0][0]']
#  Dropout1D)
#
#  activation_124 (Activation)    (None, 2000, 16)     0           ['spatial_dropout1d_124[0][0]']
#
#  conv1d_131 (Conv1D)            (None, 2000, 16)     2320        ['activation_124[0][0]']
#
#  batch_normalization_125 (Batch  (None, 2000, 16)    64          ['conv1d_131[0][0]']
#  Normalization)
#
#  spatial_dropout1d_125 (Spatial  (None, 2000, 16)    0           ['batch_normalization_125[0][0]']
#  Dropout1D)
#
#  activation_125 (Activation)    (None, 2000, 16)     0           ['spatial_dropout1d_125[0][0]']
#
#  conv1d_132 (Conv1D)            (None, 2000, 2)      34          ['activation_125[0][0]']
#
# ==================================================================================================
# Total params: 2,120,802
# Trainable params: 2,117,858
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Epoch 1/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.7529 - accuracy: 0.6068 - f1_score: 0.5581
# Epoch 1: val_f1_score improved from -inf to 0.56326, saving model to weights.h5
# 4/4 [==============================] - 22s 924ms/step - loss: 0.7529 - accuracy: 0.6068 - f1_score: 0.5581 - val_loss: 471.5576 - val_accuracy: 0.6120 - val_f1_score: 0.5633 - lr: 0.0050
# Epoch 2/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.6004 - f1_score: 0.5577
# Epoch 2: val_f1_score did not improve from 0.56326
# 4/4 [==============================] - 2s 370ms/step - loss: 0.4443 - accuracy: 0.6004 - f1_score: 0.5577 - val_loss: 2985.2676 - val_accuracy: 0.4995 - val_f1_score: 0.5633 - lr: 0.0050
# Epoch 3/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.3775 - accuracy: 0.6216 - f1_score: 0.5572
# Epoch 3: val_f1_score did not improve from 0.56326
# 4/4 [==============================] - 2s 393ms/step - loss: 0.3775 - accuracy: 0.6216 - f1_score: 0.5572 - val_loss: 12527.5439 - val_accuracy: 0.9975 - val_f1_score: 0.5633 - lr: 0.0050
# Epoch 4/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.6586 - f1_score: 0.5577
# Epoch 4: val_f1_score did not improve from 0.56326
# 4/4 [==============================] - 2s 374ms/step - loss: 0.3388 - accuracy: 0.6586 - f1_score: 0.5577 - val_loss: 21976.1953 - val_accuracy: 0.9995 - val_f1_score: 0.5633 - lr: 0.0050
# Epoch 5/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.6642 - f1_score: 0.5569
# Epoch 5: val_f1_score did not improve from 0.56326
# 4/4 [==============================] - 2s 395ms/step - loss: 0.3019 - accuracy: 0.6642 - f1_score: 0.5569 - val_loss: 34005.0000 - val_accuracy: 1.0000 - val_f1_score: 0.5633 - lr: 0.0050
# Epoch 6/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.6737 - f1_score: 0.5583
# Epoch 6: val_f1_score did not improve from 0.56326
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 4/4 [==============================] - 2s 398ms/step - loss: 0.2761 - accuracy: 0.6737 - f1_score: 0.5583 - val_loss: 28126.0527 - val_accuracy: 1.0000 - val_f1_score: 0.5633 - lr: 0.0050
# Epoch 7/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.6560 - f1_score: 0.5582
# Epoch 7: val_f1_score did not improve from 0.56326
# 4/4 [==============================] - 2s 381ms/step - loss: 0.2524 - accuracy: 0.6560 - f1_score: 0.5582 - val_loss: 9792.6309 - val_accuracy: 1.0000 - val_f1_score: 0.5633 - lr: 0.0025
# Epoch 8/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.2314 - accuracy: 0.7025 - f1_score: 0.5567
# Epoch 8: val_f1_score did not improve from 0.56326
# 4/4 [==============================] - 2s 397ms/step - loss: 0.2314 - accuracy: 0.7025 - f1_score: 0.5567 - val_loss: 4547.4165 - val_accuracy: 1.0000 - val_f1_score: 0.5633 - lr: 0.0025
# Epoch 9/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 0.6756 - f1_score: 0.5586
# Epoch 9: val_f1_score did not improve from 0.56326
# 4/4 [==============================] - 2s 383ms/step - loss: 0.2267 - accuracy: 0.6756 - f1_score: 0.5586 - val_loss: 1607.1245 - val_accuracy: 1.0000 - val_f1_score: 0.5633 - lr: 0.0025
# Epoch 10/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.6511 - f1_score: 0.5572
# Epoch 10: val_f1_score did not improve from 0.56326
# 4/4 [==============================] - 2s 381ms/step - loss: 0.2100 - accuracy: 0.6511 - f1_score: 0.5572 - val_loss: 668.1489 - val_accuracy: 1.0000 - val_f1_score: 0.5633 - lr: 0.0025
# Epoch 11/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.1954 - accuracy: 0.6911 - f1_score: 0.5593
# Epoch 11: val_f1_score did not improve from 0.56326
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 4/4 [==============================] - 2s 383ms/step - loss: 0.1954 - accuracy: 0.6911 - f1_score: 0.5593 - val_loss: 264.4163 - val_accuracy: 1.0000 - val_f1_score: 0.5633 - lr: 0.0025
# Epoch 11: early stopping
