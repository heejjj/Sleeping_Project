# %% [markdown]
# <a href="https://colab.research.google.com/github/heejjj/Sleeping_Project/blob/main/binary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # weekday binary

# %%
weekday = pd.read_csv('/content/drive/MyDrive/KDT_project/Hackathon/CNNsegmentation/data/weekday.csv')
weekday = weekday.drop('Unnamed: 0', axis=1)
print(weekday.shape)
# Out:
# (1434, 7)

# %%
weekday["Duration (hr)"] = weekday["Duration (hr)"].astype('float') * 1000
weekday['Value']= weekday['Value'].replace('Core',1)
weekday['Value']= weekday['Value'].replace('REM',0)
weekday['Value']= weekday['Value'].replace('Deep',0)
weekday['Value']= weekday['Value'].replace('Awake',0)
tmp = weekday[["Duration (hr)", "Value"]]
tmp = np.array(tmp)

x_list = []
for x in tmp:
  if x[1] != 0:
    timeseries = np.ones([int(x[0])]) * x[1]
    x_list.append(timeseries)
  else:
    timeseries = np.zeros([int(x[0])])
    x_list.append(timeseries)

ts = np.concatenate(x_list)
print(ts.shape)
# Out:
# (378383,)

# %%
y = ts
x = np.arange(len(y))

plt.plot(x, y, color='black',linewidth=2)

# %%
## 해당 경로에 있는 .csv 파일명 리스트 가져오기

import os

path = '/content/drive/MyDrive/KDT_project/HACKATHON/data/day_split_weekday'
file_list = os.listdir(path)
file_name = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
cd /content/drive/MyDrive/KDT_project/HACKATHON/data/day_split_weekday
# Out:
# /content/drive/MyDrive/KDT_project/HACKATHON/data/day_split_weekday

# %%
len_list = []
for file in file_name:
  df = pd.read_csv(file)
  df = df.drop('Unnamed: 0', axis=1)

  tmp = df
  tmp["Duration (hr)"] = tmp["Duration (hr)"].astype('float') * 1000
  tmp['Value']= tmp['Value'].replace('Core',2)
  tmp['Value']= tmp['Value'].replace('REM',3)
  tmp['Value']= tmp['Value'].replace('Deep',1)
  tmp['Value']= tmp['Value'].replace('Awake',4)
  tmp = tmp[["Duration (hr)", "Value"]]
  tmp = np.array(tmp)

  x_list = []
  for x in tmp:
    if x[1] != 0:
      timeseries = np.ones([int(x[0])]) * x[1]
      x_list.append(timeseries)

  ts = np.concatenate(x_list)

  
  len_list.append(len(ts))

# %%
sum(len_list) / len(len_list)
# Out:
# 7567.66

# %%
import numpy as np
import tensorflow as tf

# 데이터 전처리를 위한 라이브러리
import json
from scipy.signal import butter, lfilter, medfilt

# 모델 학습을 위한 라이브러리
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, MaxPooling1D
from tensorflow.keras.layers import Conv1DTranspose, concatenate, Activation, SpatialDropout1D

# 성능평가 함수를 위한 라이브러리
from tensorflow.keras import backend as K

# 시각화를 위한 라이브러리
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd

weekday = pd.read_csv('/content/drive/MyDrive/KDT_project/Hackathon/CNNsegmentation/data/weekday.csv')
weekend = pd.read_csv('/content/drive/MyDrive/KDT_project/Hackathon/CNNsegmentation/data/weekend.csv')
weekday = weekday.drop('Unnamed: 0', axis=1)
weekend = weekend.drop('Unnamed: 0', axis=1)
print(weekday.shape, weekend.shape)
# Out:
# (1434, 7) (575, 7)

# %%
img_weekday = weekday.iloc[:,[2,3]]
img_weekday["Duration (hr)"] = img_weekday["Duration (hr)"].astype('float') * 1000
img_weekday['Value']= img_weekday['Value'].replace('Core',1)
img_weekday['Value']= img_weekday['Value'].replace('REM',0)
img_weekday['Value']= img_weekday['Value'].replace('Deep',0)
img_weekday['Value']= img_weekday['Value'].replace('Awake',0)
img_weekday = img_weekday[["Duration (hr)", "Value"]]
img_weekday = np.array(img_weekday)

x_list = []   # 라벨을 duration 만큼 반복한 array를 list에 append
for x in img_weekday:
  if x[1] != 0:
    timeseries = np.ones([int(x[0])]) * x[1]
    x_list.append(timeseries)
  else:
    timeseries = np.zeros([int(x[0])]) * x[1]
    x_list.append(timeseries)

ts = np.concatenate(x_list)[:-3383]   # 7567로 나누어떨어지기 위해 데이터 버림.
print(ts.shape)
ts
tmp = ts.reshape(50, 7500, -1)
print(tmp.shape)
# Out:
# (375000,)
# (50, 7500, 1)

# %%
# 변수 정의하기
# variables
FREQUENCY_OF_DATASET = 500   # 심박수 한 사이클. 1/Hz = 주기. 일단 해보고 바꾼다면 2000

num_classes = 2 # Core, Not-Core

# %% [markdown]
# # 데이터 증강

# %%
def augmentation(dataset, ratio = 0.8):
  train_idx = int(50 * ratio)  # 80%를 트레인세트로 분류
  idx = np.arange(50)        # 0 ~ 49
  np.random.shuffle(idx)

  x = dataset[:][idx]
  y = dataset[:][idx]

  # 2. Split into 8:2
  tmp_train_x = x[:train_idx]
  tmp_valid_x = x[train_idx:]
  tmp_train_y = y[:train_idx]
  tmp_valid_y = y[train_idx:]

  # 3. Augmentation on Train and Valid dataset
  # step 설명 : 250 (0.5초) 이동하며 4초 신호를 augmentation한다.
  step = 250

  N_train = 1500  # 여유있게 범위를 줌
  N_valid = 400

  train_x, train_y = np.zeros((N_train, 2000, 1), dtype=np.float32), np.zeros((N_train, 2000, 2), dtype=np.float32) 
  valid_x, valid_y = np.zeros((N_valid, 2000, 1), dtype=np.float32), np.zeros((N_valid, 2000, 2), dtype=np.float32) 
  # print(N_train, N_valid)
  print("Start Augmentation")

  # 4.1. Train
  t_cnt, v_cnt = 0, 0
  for patient in range(train_idx):
    tmp = tmp_train_y[patient]

    # tmp = np.argmax(tmp[:, 1:], axis=-1) 
    tmp = np.nonzero(tmp)[0]            # 0이 아닌 값들의 index 들을 반환해 주는 함수
    start_idx, end_idx = tmp[0], tmp[-1]
    length = end_idx - start_idx + 1

    tmp_x = tmp_train_x[patient, start_idx:end_idx + 1]
    tmp_y = tmp_train_y[patient, start_idx:end_idx + 1]
    for idx in range(0, length-2000, step):        # 원본 15초에서 6초만큼씩 잘라, step 만큼 이동하여 데이터 증강
      train_x[t_cnt] = tmp_x[idx:idx + 2000, :]
      train_y[t_cnt] = tmp_y[idx:idx + 2000, :]
      t_cnt += 1
  print(f"Number of Train set : {t_cnt}")

  # # 4.2. Valid
  for patient in range(50-train_idx):
    tmp = tmp_valid_y[patient]
    
    tmp = np.nonzero(tmp)[0]  
    start_idx, end_idx = tmp[0], tmp[-1]
    length = end_idx - start_idx + 1

    tmp_x = tmp_valid_x[patient, start_idx:end_idx + 1]
    tmp_y = tmp_valid_y[patient, start_idx:end_idx + 1]
    for idx in range(0, length-2000, step):
      valid_x[v_cnt] = tmp_x[idx:idx + 2000, :]
      valid_y[v_cnt] = tmp_y[idx:idx + 2000, :]
      v_cnt += 1
  print(f"Number of Valid set : {v_cnt}")

  train_x, train_y = train_x[:t_cnt], train_y[:t_cnt]
  valid_x, valid_y = valid_x[:v_cnt], valid_y[:v_cnt]

  # 5. Shuffle and Save
  print("\nStart saving the dataset...")
  idx = np.arange(t_cnt)
  np.random.shuffle(idx)
  train_x = train_x[idx]
  train_y = train_y[idx]

  np.save(f"train_x", train_x)
  np.save(f"train_y", train_y)

  np.save(f"valid_x", valid_x)
  np.save(f"valid_y", valid_y)
  print("Complete saving\n")

# %% [markdown]
# # 모델 설계

# %%
def UNet1D():
    num_filter = 16

    inputs = Input((2000, 1))  # length of 4 sec signal is 2,000

    # Encoder
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(inputs)
    # kernel_initializer : kernel가중치 행렬의 초기화 프로그램입니다( 참조 keras.initializers). 기본값은 'glorot_uniform'입니다.
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o1 = Activation('relu')(x)
    x = MaxPooling1D(2)(o1)

    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o2 = Activation('relu')(x)
    x = MaxPooling1D(2)(o2)

    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o3 = Activation('relu')(x)
    x = MaxPooling1D(2)(o3)

    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o4 = Activation('relu')(x)
    x = MaxPooling1D(2)(o4)

    x = Conv1D(num_filter*16, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*16, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)  

    # Decoder
    x = Conv1DTranspose(num_filter*8, 8, strides=2, padding='same')(x)
    print(x.shape, o4.shape)
    x = concatenate([x, o4])
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter*4, 8, strides=2, padding='same')(x)
    print(x.shape, o3.shape)
    x = concatenate([x, o3])
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter*2, 8, strides=2, padding='same')(x)
    print(x.shape, o2.shape)
    x = concatenate([x, o2])
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter, 8, strides=2, padding='same')(x)
    print(x.shape, o1.shape)
    x = concatenate([x, o1])
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    outputs = Conv1D(num_classes, 1, activation='softmax', kernel_initializer='he_normal')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # 성능평가 함수 정의

# %%
# 1. F1-Score = Dice score
def f1_score(y_true, y_pred):
    smooth = 0.0001
    intersection = K.sum(y_true * y_pred, axis=[1, 2])
    union = K.sum(y_true, axis=[1, 2]) + K.sum(y_pred, axis=[1, 2])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

class f1_loss(tf.losses.Loss):
    def __init__(self):
        super(f1_loss, self).__init__(reduction='auto', name="f1_loss")

    def call(self, y_true, y_pred):
        return 1 - f1_score(y_true, y_pred)


# 2. Jaccard = IoU
def Jaccard(y_true, y_pred):
    smooth = 0.0001
    intersection = K.sum(y_true * y_pred, axis=[1, 2])
    union = K.sum(y_true, axis=[1, 2]) + K.sum(y_pred, axis=[1, 2])
    return K.mean((intersection + smooth) / (union - intersection + smooth), axis=0)

class JaccardLoss(tf.losses.Loss):
    def __init__(self):
        super(JaccardLoss, self).__init__(reduction='auto', name="JaccardLoss")

    def call(self, y_true, y_pred):
        return 1 - Jaccard(y_true, y_pred)

# %% [markdown]
# # 예측함수 정의

# %%
def Predict(test, n_sample=5):
    '''
    Input
        - test: [valid_x, valid_y]
        - n_sample: 보여줄 샘플 갯수
    테스트셋에 대해서 예측한 결과와 실제 labeling 데이터를 시각화한다.    
    '''
    model = UNet1D()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
                  loss='binary_crossentropy',
                  metrics=[Jaccard, f1_score])
    model.load_weights("weights.h5")

    for i, test_ecg in enumerate(test[0]): # valid_x
        pred = model.predict(np.reshape(test_ecg, (1, 2000, 1)))
        true = np.argmax(test[1][i], axis=-1)
        pred = np.argmax(pred[0], axis=-1)

        fig, ax = plt.subplots(3, 1, figsize=(20, 12))

        ax[0].plot(test_ecg[:, 1])
        ax[0].set_title(f"ECG_{i}'s lead II", fontsize=10)

        ax[1].plot(true)
        ax[1].set_title(f"ECG_{i}'s Groud Truth", fontsize=10)

        ax[2].plot(pred)
        ax[2].set_title(f"ECG_{i}'s Prediction", fontsize=10)

        plt.show()
        
        # 20개의 샘플만 보여준 후 멈춤
        if i == n_sample - 1:
            break

# %%
# Augmentation
augmentation(tmp)
del tmp
# Out:
# Start Augmentation
# Number of Train set : 872
# Number of Valid set : 215
#
# Start saving the dataset...
# Complete saving

# %%
train = [np.load("train_x.npy"), np.load("train_y.npy")]
valid = [np.load("valid_x.npy"), np.load("valid_y.npy")]

# %% [markdown]
# # 모델 학습

# %%
# 4. Model
print("Start Training")
batch_size = 256
lr = 0.005
epochs = 2000

model = UNet1D()
model.summary()
# Out:
# Start Training
# (None, 250, 128) (None, 250, 128)
# (None, 500, 64) (None, 500, 64)
# (None, 1000, 32) (None, 1000, 32)
# (None, 2000, 16) (None, 2000, 16)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 2000, 1)]    0           []
#
#  conv1d (Conv1D)                (None, 2000, 16)     160         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 2000, 16)    64          ['conv1d[0][0]']
#  alization)
#
#  spatial_dropout1d (SpatialDrop  (None, 2000, 16)    0           ['batch_normalization[0][0]']
#  out1D)
#
#  activation (Activation)        (None, 2000, 16)     0           ['spatial_dropout1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 2000, 16)     2320        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 2000, 16)    64          ['conv1d_1[0][0]']
#  rmalization)
#
#  spatial_dropout1d_1 (SpatialDr  (None, 2000, 16)    0           ['batch_normalization_1[0][0]']
#  opout1D)
#
#  activation_1 (Activation)      (None, 2000, 16)     0           ['spatial_dropout1d_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 1000, 16)     0           ['activation_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1000, 32)     4640        ['max_pooling1d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 1000, 32)    128         ['conv1d_2[0][0]']
#  rmalization)
#
#  spatial_dropout1d_2 (SpatialDr  (None, 1000, 32)    0           ['batch_normalization_2[0][0]']
#  opout1D)
#
#  activation_2 (Activation)      (None, 1000, 32)     0           ['spatial_dropout1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 1000, 32)     9248        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 1000, 32)    128         ['conv1d_3[0][0]']
#  rmalization)
#
#  spatial_dropout1d_3 (SpatialDr  (None, 1000, 32)    0           ['batch_normalization_3[0][0]']
#  opout1D)
#
#  activation_3 (Activation)      (None, 1000, 32)     0           ['spatial_dropout1d_3[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 500, 32)     0           ['activation_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 500, 64)      18496       ['max_pooling1d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 500, 64)     256         ['conv1d_4[0][0]']
#  rmalization)
#
#  spatial_dropout1d_4 (SpatialDr  (None, 500, 64)     0           ['batch_normalization_4[0][0]']
#  opout1D)
#
#  activation_4 (Activation)      (None, 500, 64)      0           ['spatial_dropout1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 500, 64)      36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 500, 64)     256         ['conv1d_5[0][0]']
#  rmalization)
#
#  spatial_dropout1d_5 (SpatialDr  (None, 500, 64)     0           ['batch_normalization_5[0][0]']
#  opout1D)
#
#  activation_5 (Activation)      (None, 500, 64)      0           ['spatial_dropout1d_5[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 250, 64)     0           ['activation_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 250, 128)     73856       ['max_pooling1d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 250, 128)    512         ['conv1d_6[0][0]']
#  rmalization)
#
#  spatial_dropout1d_6 (SpatialDr  (None, 250, 128)    0           ['batch_normalization_6[0][0]']
#  opout1D)
#
#  activation_6 (Activation)      (None, 250, 128)     0           ['spatial_dropout1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 250, 128)     147584      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 250, 128)    512         ['conv1d_7[0][0]']
#  rmalization)
#
#  spatial_dropout1d_7 (SpatialDr  (None, 250, 128)    0           ['batch_normalization_7[0][0]']
#  opout1D)
#
#  activation_7 (Activation)      (None, 250, 128)     0           ['spatial_dropout1d_7[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 125, 128)    0           ['activation_7[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 125, 256)     295168      ['max_pooling1d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 125, 256)    1024        ['conv1d_8[0][0]']
#  rmalization)
#
#  spatial_dropout1d_8 (SpatialDr  (None, 125, 256)    0           ['batch_normalization_8[0][0]']
#  opout1D)
#
#  activation_8 (Activation)      (None, 125, 256)     0           ['spatial_dropout1d_8[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 125, 256)     590080      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 125, 256)    1024        ['conv1d_9[0][0]']
#  rmalization)
#
#  spatial_dropout1d_9 (SpatialDr  (None, 125, 256)    0           ['batch_normalization_9[0][0]']
#  opout1D)
#
#  activation_9 (Activation)      (None, 125, 256)     0           ['spatial_dropout1d_9[0][0]']
#
#  conv1d_transpose (Conv1DTransp  (None, 250, 128)    262272      ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 250, 256)     0           ['conv1d_transpose[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 250, 128)     295040      ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 250, 128)    512         ['conv1d_10[0][0]']
#  ormalization)
#
#  spatial_dropout1d_10 (SpatialD  (None, 250, 128)    0           ['batch_normalization_10[0][0]']
#  ropout1D)
#
#  activation_10 (Activation)     (None, 250, 128)     0           ['spatial_dropout1d_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 250, 128)     147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 250, 128)    512         ['conv1d_11[0][0]']
#  ormalization)
#
#  spatial_dropout1d_11 (SpatialD  (None, 250, 128)    0           ['batch_normalization_11[0][0]']
#  ropout1D)
#
#  activation_11 (Activation)     (None, 250, 128)     0           ['spatial_dropout1d_11[0][0]']
#
#  conv1d_transpose_1 (Conv1DTran  (None, 500, 64)     65600       ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 500, 128)     0           ['conv1d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 500, 64)      73792       ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 500, 64)     256         ['conv1d_12[0][0]']
#  ormalization)
#
#  spatial_dropout1d_12 (SpatialD  (None, 500, 64)     0           ['batch_normalization_12[0][0]']
#  ropout1D)
#
#  activation_12 (Activation)     (None, 500, 64)      0           ['spatial_dropout1d_12[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 500, 64)      36928       ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 500, 64)     256         ['conv1d_13[0][0]']
#  ormalization)
#
#  spatial_dropout1d_13 (SpatialD  (None, 500, 64)     0           ['batch_normalization_13[0][0]']
#  ropout1D)
#
#  activation_13 (Activation)     (None, 500, 64)      0           ['spatial_dropout1d_13[0][0]']
#
#  conv1d_transpose_2 (Conv1DTran  (None, 1000, 32)    16416       ['activation_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 1000, 64)     0           ['conv1d_transpose_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 1000, 32)     18464       ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 1000, 32)    128         ['conv1d_14[0][0]']
#  ormalization)
#
#  spatial_dropout1d_14 (SpatialD  (None, 1000, 32)    0           ['batch_normalization_14[0][0]']
#  ropout1D)
#
#  activation_14 (Activation)     (None, 1000, 32)     0           ['spatial_dropout1d_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 1000, 32)     9248        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 1000, 32)    128         ['conv1d_15[0][0]']
#  ormalization)
#
#  spatial_dropout1d_15 (SpatialD  (None, 1000, 32)    0           ['batch_normalization_15[0][0]']
#  ropout1D)
#
#  activation_15 (Activation)     (None, 1000, 32)     0           ['spatial_dropout1d_15[0][0]']
#
#  conv1d_transpose_3 (Conv1DTran  (None, 2000, 16)    4112        ['activation_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 2000, 32)     0           ['conv1d_transpose_3[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 2000, 16)     4624        ['concatenate_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 2000, 16)    64          ['conv1d_16[0][0]']
#  ormalization)
#
#  spatial_dropout1d_16 (SpatialD  (None, 2000, 16)    0           ['batch_normalization_16[0][0]']
#  ropout1D)
#
#  activation_16 (Activation)     (None, 2000, 16)     0           ['spatial_dropout1d_16[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 2000, 16)     2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 2000, 16)    64          ['conv1d_17[0][0]']
#  ormalization)
#
#  spatial_dropout1d_17 (SpatialD  (None, 2000, 16)    0           ['batch_normalization_17[0][0]']
#  ropout1D)
#
#  activation_17 (Activation)     (None, 2000, 16)     0           ['spatial_dropout1d_17[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 2000, 2)      34          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 2,120,802
# Trainable params: 2,117,858
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
# 5. Train
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss='binary_crossentropy',
              metrics=[Jaccard, f1_score])

callbacks_list = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="weights.h5",
        monitor="val_f1_score",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1),

    # tf.keras.callbacks.EarlyStopping(
    #     monitor="val_f1_score",
    #     min_delta=0.005,
    #     mode="max",
    #     patience=10,
    #     verbose=1),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_f1_score',
        factor=0.5,
        patience=5,
        mode='max',
        min_delta=0.01,
        cooldown=0,
        min_lr=0.0001,
        verbose=1)
]

history = model.fit(train[0], train[1],
                    validation_data=(valid[0], valid[1]),
                    callbacks=callbacks_list,
                    epochs=epochs,
                    batch_size=batch_size,
                    shuffle=True,
                    )


loss = history.history['loss']
val_loss = history.history['val_loss']
Jaccard = history.history["Jaccard"]
val_Jaccard = history.history["val_Jaccard"]
f1 = history.history["f1_score"]
val_f1 = history.history["val_f1_score"]

epochs_range = range(len(loss))
fig, ax = plt.subplots(1, 3, figsize = (20, 12))
ax[0].plot(epochs_range, loss, label='Training Loss')
ax[0].plot(epochs_range, val_loss, label='Validation Loss')

ax[1].plot(epochs_range, Jaccard, label='Training Jaccard')
ax[1].plot(epochs_range, val_Jaccard, label='Validation Jaccard')

ax[2].plot(epochs_range, f1, label='Training f1-score')
ax[2].plot(epochs_range, val_f1, label='Validation f1-score')
plt.show()

del model, history, train
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 751/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0103 - Jaccard: 0.3910 - f1_score: 0.5606
# Epoch 751: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0103 - Jaccard: 0.3910 - f1_score: 0.5606 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 752/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0094 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 752: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0094 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 753/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0104 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 753: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0104 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 754/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0104 - Jaccard: 0.3914 - f1_score: 0.5610
# Epoch 754: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0104 - Jaccard: 0.3914 - f1_score: 0.5610 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 755/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0098 - Jaccard: 0.3890 - f1_score: 0.5586
# Epoch 755: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 357ms/step - loss: 0.0098 - Jaccard: 0.3890 - f1_score: 0.5586 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 756/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0099 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 756: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 379ms/step - loss: 0.0099 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 757/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - Jaccard: 0.3904 - f1_score: 0.5601
# Epoch 757: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 383ms/step - loss: 0.0088 - Jaccard: 0.3904 - f1_score: 0.5601 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 758/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0109 - Jaccard: 0.3916 - f1_score: 0.5614
# Epoch 758: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 393ms/step - loss: 0.0109 - Jaccard: 0.3916 - f1_score: 0.5614 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 759/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0108 - Jaccard: 0.3909 - f1_score: 0.5606
# Epoch 759: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 379ms/step - loss: 0.0108 - Jaccard: 0.3909 - f1_score: 0.5606 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 760/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3916 - f1_score: 0.5613
# Epoch 760: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0082 - Jaccard: 0.3916 - f1_score: 0.5613 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 761/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0106 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 761: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 376ms/step - loss: 0.0106 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 762/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0118 - Jaccard: 0.3895 - f1_score: 0.5590
# Epoch 762: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0118 - Jaccard: 0.3895 - f1_score: 0.5590 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 763/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0099 - Jaccard: 0.3896 - f1_score: 0.5591
# Epoch 763: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0099 - Jaccard: 0.3896 - f1_score: 0.5591 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 764/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0095 - Jaccard: 0.3896 - f1_score: 0.5592
# Epoch 764: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0095 - Jaccard: 0.3896 - f1_score: 0.5592 - val_loss: 0.0023 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 765/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0095 - Jaccard: 0.3904 - f1_score: 0.5601
# Epoch 765: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0095 - Jaccard: 0.3904 - f1_score: 0.5601 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 766/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0098 - Jaccard: 0.3911 - f1_score: 0.5608
# Epoch 766: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 391ms/step - loss: 0.0098 - Jaccard: 0.3911 - f1_score: 0.5608 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 767/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0101 - Jaccard: 0.3901 - f1_score: 0.5597
# Epoch 767: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 391ms/step - loss: 0.0101 - Jaccard: 0.3901 - f1_score: 0.5597 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 768/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0087 - Jaccard: 0.3901 - f1_score: 0.5597
# Epoch 768: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0087 - Jaccard: 0.3901 - f1_score: 0.5597 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 769/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0093 - Jaccard: 0.3895 - f1_score: 0.5590
# Epoch 769: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0093 - Jaccard: 0.3895 - f1_score: 0.5590 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 770/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0089 - Jaccard: 0.3907 - f1_score: 0.5602
# Epoch 770: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0089 - Jaccard: 0.3907 - f1_score: 0.5602 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 771/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0098 - Jaccard: 0.3910 - f1_score: 0.5606
# Epoch 771: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 370ms/step - loss: 0.0098 - Jaccard: 0.3910 - f1_score: 0.5606 - val_loss: 0.0022 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 772/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0100 - Jaccard: 0.3898 - f1_score: 0.5593
# Epoch 772: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0100 - Jaccard: 0.3898 - f1_score: 0.5593 - val_loss: 0.0021 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 773/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0116 - Jaccard: 0.3907 - f1_score: 0.5603
# Epoch 773: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0116 - Jaccard: 0.3907 - f1_score: 0.5603 - val_loss: 0.0021 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 774/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0096 - Jaccard: 0.3907 - f1_score: 0.5602
# Epoch 774: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0096 - Jaccard: 0.3907 - f1_score: 0.5602 - val_loss: 0.0021 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 775/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0096 - Jaccard: 0.3905 - f1_score: 0.5601
# Epoch 775: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0096 - Jaccard: 0.3905 - f1_score: 0.5601 - val_loss: 0.0021 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 776/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0113 - Jaccard: 0.3895 - f1_score: 0.5590
# Epoch 776: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 389ms/step - loss: 0.0113 - Jaccard: 0.3895 - f1_score: 0.5590 - val_loss: 0.0021 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 777/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0096 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 777: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 368ms/step - loss: 0.0096 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 0.0021 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 778/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0094 - Jaccard: 0.3909 - f1_score: 0.5606
# Epoch 778: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0094 - Jaccard: 0.3909 - f1_score: 0.5606 - val_loss: 0.0021 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 779/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0101 - Jaccard: 0.3909 - f1_score: 0.5606
# Epoch 779: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0101 - Jaccard: 0.3909 - f1_score: 0.5606 - val_loss: 0.0020 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 780/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0097 - Jaccard: 0.3894 - f1_score: 0.5589
# Epoch 780: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0097 - Jaccard: 0.3894 - f1_score: 0.5589 - val_loss: 0.0020 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 781/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0087 - Jaccard: 0.3905 - f1_score: 0.5601
# Epoch 781: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 387ms/step - loss: 0.0087 - Jaccard: 0.3905 - f1_score: 0.5601 - val_loss: 0.0020 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 782/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0093 - Jaccard: 0.3906 - f1_score: 0.5603
# Epoch 782: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0093 - Jaccard: 0.3906 - f1_score: 0.5603 - val_loss: 0.0020 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 783/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0096 - Jaccard: 0.3899 - f1_score: 0.5595
# Epoch 783: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0096 - Jaccard: 0.3899 - f1_score: 0.5595 - val_loss: 0.0020 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 784/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0092 - Jaccard: 0.3902 - f1_score: 0.5597
# Epoch 784: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 374ms/step - loss: 0.0092 - Jaccard: 0.3902 - f1_score: 0.5597 - val_loss: 0.0020 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 785/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0083 - Jaccard: 0.3912 - f1_score: 0.5609
# Epoch 785: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 392ms/step - loss: 0.0083 - Jaccard: 0.3912 - f1_score: 0.5609 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 786/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0098 - Jaccard: 0.3908 - f1_score: 0.5604
# Epoch 786: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 369ms/step - loss: 0.0098 - Jaccard: 0.3908 - f1_score: 0.5604 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 787/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0098 - Jaccard: 0.3900 - f1_score: 0.5596
# Epoch 787: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0098 - Jaccard: 0.3900 - f1_score: 0.5596 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 788/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - Jaccard: 0.3914 - f1_score: 0.5611
# Epoch 788: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 384ms/step - loss: 0.0086 - Jaccard: 0.3914 - f1_score: 0.5611 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 789/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0118 - Jaccard: 0.3905 - f1_score: 0.5602
# Epoch 789: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0118 - Jaccard: 0.3905 - f1_score: 0.5602 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 790/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - Jaccard: 0.3913 - f1_score: 0.5610
# Epoch 790: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0088 - Jaccard: 0.3913 - f1_score: 0.5610 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 791/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0102 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 791: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0102 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 792/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0090 - Jaccard: 0.3910 - f1_score: 0.5606
# Epoch 792: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0090 - Jaccard: 0.3910 - f1_score: 0.5606 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 793/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0090 - Jaccard: 0.3904 - f1_score: 0.5599
# Epoch 793: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0090 - Jaccard: 0.3904 - f1_score: 0.5599 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 794/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0112 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 794: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 394ms/step - loss: 0.0112 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 795/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0095 - Jaccard: 0.3911 - f1_score: 0.5608
# Epoch 795: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 374ms/step - loss: 0.0095 - Jaccard: 0.3911 - f1_score: 0.5608 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 796/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0092 - Jaccard: 0.3910 - f1_score: 0.5606
# Epoch 796: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0092 - Jaccard: 0.3910 - f1_score: 0.5606 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 797/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0091 - Jaccard: 0.3898 - f1_score: 0.5593
# Epoch 797: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0091 - Jaccard: 0.3898 - f1_score: 0.5593 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 798/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0117 - Jaccard: 0.3908 - f1_score: 0.5605
# Epoch 798: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0117 - Jaccard: 0.3908 - f1_score: 0.5605 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 799/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0092 - Jaccard: 0.3911 - f1_score: 0.5608
# Epoch 799: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0092 - Jaccard: 0.3911 - f1_score: 0.5608 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 800/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - Jaccard: 0.3904 - f1_score: 0.5601
# Epoch 800: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0086 - Jaccard: 0.3904 - f1_score: 0.5601 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 801/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0114 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 801: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0114 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 802/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0089 - Jaccard: 0.3897 - f1_score: 0.5593
# Epoch 802: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0089 - Jaccard: 0.3897 - f1_score: 0.5593 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 803/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - Jaccard: 0.3902 - f1_score: 0.5599
# Epoch 803: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 391ms/step - loss: 0.0086 - Jaccard: 0.3902 - f1_score: 0.5599 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 804/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0076 - Jaccard: 0.3892 - f1_score: 0.5587
# Epoch 804: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 373ms/step - loss: 0.0076 - Jaccard: 0.3892 - f1_score: 0.5587 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 805/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0080 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 805: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0080 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 806/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0091 - Jaccard: 0.3905 - f1_score: 0.5601
# Epoch 806: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0091 - Jaccard: 0.3905 - f1_score: 0.5601 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 807/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0085 - Jaccard: 0.3910 - f1_score: 0.5606
# Epoch 807: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0085 - Jaccard: 0.3910 - f1_score: 0.5606 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 808/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3894 - f1_score: 0.5589
# Epoch 808: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0082 - Jaccard: 0.3894 - f1_score: 0.5589 - val_loss: 0.0019 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 809/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0087 - Jaccard: 0.3901 - f1_score: 0.5597
# Epoch 809: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0087 - Jaccard: 0.3901 - f1_score: 0.5597 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 810/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0078 - Jaccard: 0.3899 - f1_score: 0.5595
# Epoch 810: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0078 - Jaccard: 0.3899 - f1_score: 0.5595 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 811/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0074 - Jaccard: 0.3907 - f1_score: 0.5603
# Epoch 811: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 395ms/step - loss: 0.0074 - Jaccard: 0.3907 - f1_score: 0.5603 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 812/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - Jaccard: 0.3911 - f1_score: 0.5608
# Epoch 812: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0086 - Jaccard: 0.3911 - f1_score: 0.5608 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 813/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - Jaccard: 0.3900 - f1_score: 0.5596
# Epoch 813: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 378ms/step - loss: 0.0088 - Jaccard: 0.3900 - f1_score: 0.5596 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 814/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0076 - Jaccard: 0.3909 - f1_score: 0.5605
# Epoch 814: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 385ms/step - loss: 0.0076 - Jaccard: 0.3909 - f1_score: 0.5605 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 815/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0095 - Jaccard: 0.3908 - f1_score: 0.5604
# Epoch 815: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0095 - Jaccard: 0.3908 - f1_score: 0.5604 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 816/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0146 - Jaccard: 0.3912 - f1_score: 0.5608
# Epoch 816: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 392ms/step - loss: 0.0146 - Jaccard: 0.3912 - f1_score: 0.5608 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 817/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0085 - Jaccard: 0.3901 - f1_score: 0.5596
# Epoch 817: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 385ms/step - loss: 0.0085 - Jaccard: 0.3901 - f1_score: 0.5596 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 818/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0076 - Jaccard: 0.3898 - f1_score: 0.5593
# Epoch 818: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 388ms/step - loss: 0.0076 - Jaccard: 0.3898 - f1_score: 0.5593 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 819/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3900 - f1_score: 0.5595
# Epoch 819: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0082 - Jaccard: 0.3900 - f1_score: 0.5595 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 820/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0090 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 820: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 376ms/step - loss: 0.0090 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 821/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0093 - Jaccard: 0.3907 - f1_score: 0.5603
# Epoch 821: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 386ms/step - loss: 0.0093 - Jaccard: 0.3907 - f1_score: 0.5603 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 822/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - Jaccard: 0.3909 - f1_score: 0.5606
# Epoch 822: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 375ms/step - loss: 0.0086 - Jaccard: 0.3909 - f1_score: 0.5606 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 823/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0097 - Jaccard: 0.3902 - f1_score: 0.5597
# Epoch 823: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0097 - Jaccard: 0.3902 - f1_score: 0.5597 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 824/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - Jaccard: 0.3911 - f1_score: 0.5607
# Epoch 824: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0088 - Jaccard: 0.3911 - f1_score: 0.5607 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 825/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0089 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 825: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 379ms/step - loss: 0.0089 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 0.0018 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 826/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0074 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 826: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 378ms/step - loss: 0.0074 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0017 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 827/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0084 - Jaccard: 0.3906 - f1_score: 0.5601
# Epoch 827: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0084 - Jaccard: 0.3906 - f1_score: 0.5601 - val_loss: 0.0017 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 828/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3908 - f1_score: 0.5605
# Epoch 828: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0082 - Jaccard: 0.3908 - f1_score: 0.5605 - val_loss: 0.0017 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 829/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3905 - f1_score: 0.5601
# Epoch 829: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 372ms/step - loss: 0.0082 - Jaccard: 0.3905 - f1_score: 0.5601 - val_loss: 0.0017 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 830/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0134 - Jaccard: 0.3905 - f1_score: 0.5601
# Epoch 830: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 373ms/step - loss: 0.0134 - Jaccard: 0.3905 - f1_score: 0.5601 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 831/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0073 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 831: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 377ms/step - loss: 0.0073 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 832/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0089 - Jaccard: 0.3907 - f1_score: 0.5604
# Epoch 832: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0089 - Jaccard: 0.3907 - f1_score: 0.5604 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 833/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0097 - Jaccard: 0.3901 - f1_score: 0.5597
# Epoch 833: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 386ms/step - loss: 0.0097 - Jaccard: 0.3901 - f1_score: 0.5597 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 834/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0080 - Jaccard: 0.3905 - f1_score: 0.5602
# Epoch 834: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0080 - Jaccard: 0.3905 - f1_score: 0.5602 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 835/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0087 - Jaccard: 0.3890 - f1_score: 0.5585
# Epoch 835: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0087 - Jaccard: 0.3890 - f1_score: 0.5585 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 836/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0079 - Jaccard: 0.3899 - f1_score: 0.5595
# Epoch 836: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0079 - Jaccard: 0.3899 - f1_score: 0.5595 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 837/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0077 - Jaccard: 0.3895 - f1_score: 0.5591
# Epoch 837: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0077 - Jaccard: 0.3895 - f1_score: 0.5591 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 838/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0095 - Jaccard: 0.3909 - f1_score: 0.5605
# Epoch 838: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0095 - Jaccard: 0.3909 - f1_score: 0.5605 - val_loss: 0.0016 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 839/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0083 - Jaccard: 0.3902 - f1_score: 0.5597
# Epoch 839: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 390ms/step - loss: 0.0083 - Jaccard: 0.3902 - f1_score: 0.5597 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 840/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0084 - Jaccard: 0.3909 - f1_score: 0.5605
# Epoch 840: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 385ms/step - loss: 0.0084 - Jaccard: 0.3909 - f1_score: 0.5605 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 841/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0103 - Jaccard: 0.3908 - f1_score: 0.5605
# Epoch 841: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 383ms/step - loss: 0.0103 - Jaccard: 0.3908 - f1_score: 0.5605 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 842/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0074 - Jaccard: 0.3892 - f1_score: 0.5587
# Epoch 842: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0074 - Jaccard: 0.3892 - f1_score: 0.5587 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 843/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0093 - Jaccard: 0.3907 - f1_score: 0.5603
# Epoch 843: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0093 - Jaccard: 0.3907 - f1_score: 0.5603 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 844/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0080 - Jaccard: 0.3907 - f1_score: 0.5603
# Epoch 844: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0080 - Jaccard: 0.3907 - f1_score: 0.5603 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 845/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0083 - Jaccard: 0.3912 - f1_score: 0.5608
# Epoch 845: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0083 - Jaccard: 0.3912 - f1_score: 0.5608 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 846/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0078 - Jaccard: 0.3904 - f1_score: 0.5601
# Epoch 846: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0078 - Jaccard: 0.3904 - f1_score: 0.5601 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 847/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0090 - Jaccard: 0.3904 - f1_score: 0.5599
# Epoch 847: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0090 - Jaccard: 0.3904 - f1_score: 0.5599 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 848/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0080 - Jaccard: 0.3892 - f1_score: 0.5587
# Epoch 848: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 373ms/step - loss: 0.0080 - Jaccard: 0.3892 - f1_score: 0.5587 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 849/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0074 - Jaccard: 0.3896 - f1_score: 0.5591
# Epoch 849: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0074 - Jaccard: 0.3896 - f1_score: 0.5591 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 850/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 850: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 385ms/step - loss: 0.0088 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 851/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0088 - Jaccard: 0.3900 - f1_score: 0.5596
# Epoch 851: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0088 - Jaccard: 0.3900 - f1_score: 0.5596 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 852/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0091 - Jaccard: 0.3916 - f1_score: 0.5612
# Epoch 852: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0091 - Jaccard: 0.3916 - f1_score: 0.5612 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 853/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0084 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 853: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0084 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 854/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - Jaccard: 0.3906 - f1_score: 0.5601
# Epoch 854: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 385ms/step - loss: 0.0086 - Jaccard: 0.3906 - f1_score: 0.5601 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 855/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0074 - Jaccard: 0.3910 - f1_score: 0.5606
# Epoch 855: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0074 - Jaccard: 0.3910 - f1_score: 0.5606 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 856/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0071 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 856: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0071 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 857/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0090 - Jaccard: 0.3897 - f1_score: 0.5592
# Epoch 857: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 377ms/step - loss: 0.0090 - Jaccard: 0.3897 - f1_score: 0.5592 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 858/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0103 - Jaccard: 0.3895 - f1_score: 0.5590
# Epoch 858: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 376ms/step - loss: 0.0103 - Jaccard: 0.3895 - f1_score: 0.5590 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 859/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0103 - Jaccard: 0.3892 - f1_score: 0.5587
# Epoch 859: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0103 - Jaccard: 0.3892 - f1_score: 0.5587 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 860/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0085 - Jaccard: 0.3902 - f1_score: 0.5599
# Epoch 860: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0085 - Jaccard: 0.3902 - f1_score: 0.5599 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 861/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0099 - Jaccard: 0.3908 - f1_score: 0.5604
# Epoch 861: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0099 - Jaccard: 0.3908 - f1_score: 0.5604 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 862/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0080 - Jaccard: 0.3901 - f1_score: 0.5597
# Epoch 862: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0080 - Jaccard: 0.3901 - f1_score: 0.5597 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 863/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0085 - Jaccard: 0.3908 - f1_score: 0.5604
# Epoch 863: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0085 - Jaccard: 0.3908 - f1_score: 0.5604 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 864/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3907 - f1_score: 0.5603
# Epoch 864: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0082 - Jaccard: 0.3907 - f1_score: 0.5603 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 865/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0075 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 865: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0075 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 0.0015 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 866/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - Jaccard: 0.3903 - f1_score: 0.5600
# Epoch 866: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 374ms/step - loss: 0.0086 - Jaccard: 0.3903 - f1_score: 0.5600 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 867/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0105 - Jaccard: 0.3902 - f1_score: 0.5597
# Epoch 867: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 387ms/step - loss: 0.0105 - Jaccard: 0.3902 - f1_score: 0.5597 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 868/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0070 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 868: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0070 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 869/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0083 - Jaccard: 0.3901 - f1_score: 0.5596
# Epoch 869: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 360ms/step - loss: 0.0083 - Jaccard: 0.3901 - f1_score: 0.5596 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 870/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0087 - Jaccard: 0.3907 - f1_score: 0.5603
# Epoch 870: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0087 - Jaccard: 0.3907 - f1_score: 0.5603 - val_loss: 0.0013 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 871/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0079 - Jaccard: 0.3895 - f1_score: 0.5591
# Epoch 871: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0079 - Jaccard: 0.3895 - f1_score: 0.5591 - val_loss: 0.0013 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 872/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0071 - Jaccard: 0.3908 - f1_score: 0.5605
# Epoch 872: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0071 - Jaccard: 0.3908 - f1_score: 0.5605 - val_loss: 0.0013 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 873/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0115 - Jaccard: 0.3911 - f1_score: 0.5608
# Epoch 873: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0115 - Jaccard: 0.3911 - f1_score: 0.5608 - val_loss: 0.0013 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 874/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0086 - Jaccard: 0.3916 - f1_score: 0.5613
# Epoch 874: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0086 - Jaccard: 0.3916 - f1_score: 0.5613 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 875/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0078 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 875: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 391ms/step - loss: 0.0078 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 876/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0079 - Jaccard: 0.3922 - f1_score: 0.5618
# Epoch 876: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 368ms/step - loss: 0.0079 - Jaccard: 0.3922 - f1_score: 0.5618 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 877/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3914 - f1_score: 0.5611
# Epoch 877: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0082 - Jaccard: 0.3914 - f1_score: 0.5611 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 878/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0074 - Jaccard: 0.3899 - f1_score: 0.5595
# Epoch 878: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 359ms/step - loss: 0.0074 - Jaccard: 0.3899 - f1_score: 0.5595 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 879/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0092 - Jaccard: 0.3904 - f1_score: 0.5600
# Epoch 879: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0092 - Jaccard: 0.3904 - f1_score: 0.5600 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 880/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0109 - Jaccard: 0.3915 - f1_score: 0.5611
# Epoch 880: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0109 - Jaccard: 0.3915 - f1_score: 0.5611 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 881/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0072 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 881: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0072 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 882/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0073 - Jaccard: 0.3900 - f1_score: 0.5596
# Epoch 882: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0073 - Jaccard: 0.3900 - f1_score: 0.5596 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 883/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3900 - f1_score: 0.5595
# Epoch 883: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0082 - Jaccard: 0.3900 - f1_score: 0.5595 - val_loss: 0.0014 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 884/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0072 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 884: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0072 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 0.0013 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 885/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0082 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 885: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0082 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 0.0013 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 886/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0073 - Jaccard: 0.3907 - f1_score: 0.5604
# Epoch 886: val_f1_score did not improve from 0.55461
# ...
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0028 - Jaccard: 0.3899 - f1_score: 0.5595 - val_loss: 4.1139e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1957/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0018 - Jaccard: 0.3894 - f1_score: 0.5590
# Epoch 1957: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0018 - Jaccard: 0.3894 - f1_score: 0.5590 - val_loss: 4.0735e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1958/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - Jaccard: 0.3900 - f1_score: 0.5596
# Epoch 1958: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 372ms/step - loss: 0.0013 - Jaccard: 0.3900 - f1_score: 0.5596 - val_loss: 4.0714e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1959/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - Jaccard: 0.3910 - f1_score: 0.5607
# Epoch 1959: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 367ms/step - loss: 0.0013 - Jaccard: 0.3910 - f1_score: 0.5607 - val_loss: 4.0595e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1960/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0012 - Jaccard: 0.3905 - f1_score: 0.5601
# Epoch 1960: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0012 - Jaccard: 0.3905 - f1_score: 0.5601 - val_loss: 4.0587e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1961/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0026 - Jaccard: 0.3893 - f1_score: 0.5588
# Epoch 1961: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0026 - Jaccard: 0.3893 - f1_score: 0.5588 - val_loss: 4.0547e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1962/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0019 - Jaccard: 0.3901 - f1_score: 0.5597
# Epoch 1962: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 379ms/step - loss: 0.0019 - Jaccard: 0.3901 - f1_score: 0.5597 - val_loss: 4.0543e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1963/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0016 - Jaccard: 0.3908 - f1_score: 0.5605
# Epoch 1963: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0016 - Jaccard: 0.3908 - f1_score: 0.5605 - val_loss: 4.0511e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1964/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0020 - Jaccard: 0.3906 - f1_score: 0.5603
# Epoch 1964: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0020 - Jaccard: 0.3906 - f1_score: 0.5603 - val_loss: 4.0528e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1965/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0047 - Jaccard: 0.3900 - f1_score: 0.5595
# Epoch 1965: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 379ms/step - loss: 0.0047 - Jaccard: 0.3900 - f1_score: 0.5595 - val_loss: 4.0378e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1966/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0019 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 1966: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0019 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 4.0266e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1967/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0038 - Jaccard: 0.3888 - f1_score: 0.5582
# Epoch 1967: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0038 - Jaccard: 0.3888 - f1_score: 0.5582 - val_loss: 4.1379e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1968/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0015 - Jaccard: 0.3908 - f1_score: 0.5605
# Epoch 1968: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 377ms/step - loss: 0.0015 - Jaccard: 0.3908 - f1_score: 0.5605 - val_loss: 4.2184e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1969/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0017 - Jaccard: 0.3901 - f1_score: 0.5597
# Epoch 1969: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 375ms/step - loss: 0.0017 - Jaccard: 0.3901 - f1_score: 0.5597 - val_loss: 4.2361e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1970/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0026 - Jaccard: 0.3908 - f1_score: 0.5604
# Epoch 1970: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0026 - Jaccard: 0.3908 - f1_score: 0.5604 - val_loss: 4.2333e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1971/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0018 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 1971: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 381ms/step - loss: 0.0018 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 4.2085e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1972/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0015 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 1972: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 368ms/step - loss: 0.0015 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 4.1794e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1973/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0017 - Jaccard: 0.3912 - f1_score: 0.5609
# Epoch 1973: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 361ms/step - loss: 0.0017 - Jaccard: 0.3912 - f1_score: 0.5609 - val_loss: 4.1600e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1974/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0019 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 1974: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 378ms/step - loss: 0.0019 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 4.1283e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1975/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0019 - Jaccard: 0.3903 - f1_score: 0.5599
# Epoch 1975: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 371ms/step - loss: 0.0019 - Jaccard: 0.3903 - f1_score: 0.5599 - val_loss: 4.1144e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1976/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0025 - Jaccard: 0.3896 - f1_score: 0.5592
# Epoch 1976: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 387ms/step - loss: 0.0025 - Jaccard: 0.3896 - f1_score: 0.5592 - val_loss: 4.1008e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1977/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0022 - Jaccard: 0.3902 - f1_score: 0.5598
# Epoch 1977: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 369ms/step - loss: 0.0022 - Jaccard: 0.3902 - f1_score: 0.5598 - val_loss: 4.0797e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1978/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0023 - Jaccard: 0.3907 - f1_score: 0.5604
# Epoch 1978: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 373ms/step - loss: 0.0023 - Jaccard: 0.3907 - f1_score: 0.5604 - val_loss: 4.0597e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1979/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0026 - Jaccard: 0.3906 - f1_score: 0.5601
# Epoch 1979: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0026 - Jaccard: 0.3906 - f1_score: 0.5601 - val_loss: 4.0469e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1980/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0016 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 1980: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0016 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 4.0472e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1981/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0024 - Jaccard: 0.3894 - f1_score: 0.5590
# Epoch 1981: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0024 - Jaccard: 0.3894 - f1_score: 0.5590 - val_loss: 4.0440e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1982/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0012 - Jaccard: 0.3914 - f1_score: 0.5611
# Epoch 1982: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0012 - Jaccard: 0.3914 - f1_score: 0.5611 - val_loss: 4.0407e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1983/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0015 - Jaccard: 0.3904 - f1_score: 0.5600
# Epoch 1983: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 382ms/step - loss: 0.0015 - Jaccard: 0.3904 - f1_score: 0.5600 - val_loss: 4.0450e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1984/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0017 - Jaccard: 0.3908 - f1_score: 0.5605
# Epoch 1984: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0017 - Jaccard: 0.3908 - f1_score: 0.5605 - val_loss: 4.0205e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1985/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - Jaccard: 0.3899 - f1_score: 0.5594
# Epoch 1985: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0013 - Jaccard: 0.3899 - f1_score: 0.5594 - val_loss: 3.9514e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1986/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - Jaccard: 0.3896 - f1_score: 0.5591
# Epoch 1986: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 374ms/step - loss: 0.0013 - Jaccard: 0.3896 - f1_score: 0.5591 - val_loss: 3.9063e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1987/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0015 - Jaccard: 0.3900 - f1_score: 0.5595
# Epoch 1987: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 380ms/step - loss: 0.0015 - Jaccard: 0.3900 - f1_score: 0.5595 - val_loss: 3.8840e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1988/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0014 - Jaccard: 0.3912 - f1_score: 0.5609
# Epoch 1988: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0014 - Jaccard: 0.3912 - f1_score: 0.5609 - val_loss: 3.8728e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1989/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 1989: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 363ms/step - loss: 0.0013 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 3.8631e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1990/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0025 - Jaccard: 0.3899 - f1_score: 0.5595
# Epoch 1990: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 360ms/step - loss: 0.0025 - Jaccard: 0.3899 - f1_score: 0.5595 - val_loss: 3.8344e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1991/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0018 - Jaccard: 0.3891 - f1_score: 0.5587
# Epoch 1991: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0018 - Jaccard: 0.3891 - f1_score: 0.5587 - val_loss: 3.8289e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1992/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0019 - Jaccard: 0.3900 - f1_score: 0.5596
# Epoch 1992: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 366ms/step - loss: 0.0019 - Jaccard: 0.3900 - f1_score: 0.5596 - val_loss: 3.8174e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1993/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0024 - Jaccard: 0.3899 - f1_score: 0.5595
# Epoch 1993: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 365ms/step - loss: 0.0024 - Jaccard: 0.3899 - f1_score: 0.5595 - val_loss: 3.8090e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1994/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0018 - Jaccard: 0.3898 - f1_score: 0.5594
# Epoch 1994: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 369ms/step - loss: 0.0018 - Jaccard: 0.3898 - f1_score: 0.5594 - val_loss: 3.8019e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1995/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0016 - Jaccard: 0.3900 - f1_score: 0.5596
# Epoch 1995: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 389ms/step - loss: 0.0016 - Jaccard: 0.3900 - f1_score: 0.5596 - val_loss: 3.7958e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1996/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0016 - Jaccard: 0.3912 - f1_score: 0.5609
# Epoch 1996: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 390ms/step - loss: 0.0016 - Jaccard: 0.3912 - f1_score: 0.5609 - val_loss: 3.7921e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1997/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0018 - Jaccard: 0.3906 - f1_score: 0.5602
# Epoch 1997: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 364ms/step - loss: 0.0018 - Jaccard: 0.3906 - f1_score: 0.5602 - val_loss: 3.7870e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1998/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0013 - Jaccard: 0.3900 - f1_score: 0.5597
# Epoch 1998: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 389ms/step - loss: 0.0013 - Jaccard: 0.3900 - f1_score: 0.5597 - val_loss: 3.7665e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 1999/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0038 - Jaccard: 0.3901 - f1_score: 0.5597
# Epoch 1999: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 2s 388ms/step - loss: 0.0038 - Jaccard: 0.3901 - f1_score: 0.5597 - val_loss: 3.7538e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04
# Epoch 2000/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.0014 - Jaccard: 0.3896 - f1_score: 0.5592
# Epoch 2000: val_f1_score did not improve from 0.55461
# 4/4 [==============================] - 1s 362ms/step - loss: 0.0014 - Jaccard: 0.3896 - f1_score: 0.5592 - val_loss: 3.7296e-05 - val_Jaccard: 0.3858 - val_f1_score: 0.5546 - lr: 1.0000e-04

# %%
valid = [np.load("valid_x.npy"), np.load("valid_y.npy")]
print(valid[0].shape)

Predict(test=valid)
# Out:
# (215, 2000, 1)
# (None, 250, 128) (None, 250, 128)
# (None, 500, 64) (None, 500, 64)
# (None, 1000, 32) (None, 1000, 32)
# (None, 2000, 16) (None, 2000, 16)
# 1/1 [==============================] - 1s 1s/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-074d3b6d7965> in <cell line: 4>()
#       2 print(valid[0].shape)
#       3
# ----> 4 Predict(test=valid)
#
# <ipython-input-24-d71e00bcca6e> in Predict(test, n_sample)
#      19         fig, ax = plt.subplots(3, 1, figsize=(20, 12))
#      20
# ---> 21         ax[0].plot(test_ecg[:, 1])
#      22         ax[0].set_title(f"ECG_{i}'s lead II", fontsize=10)
#      23
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
